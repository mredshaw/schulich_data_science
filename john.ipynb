# %%
import pandas as pd
import sqlalchemy as sa
import requests

# %%
resource_id = '23172a73-7b85-49bd-9064-d600d2b21d37'
limit = 1500
offset = 0

# %%
api_url = 'https://data.ontario.ca/api/3/action/datastore_search?resource_id={}&limit={}&offset={}'.format(resource_id, limit, offset)

# %%
print(api_url)
# Out:
# https://data.ontario.ca/api/3/action/datastore_search?resource_id=23172a73-7b85-49bd-9064-d600d2b21d37&limit=1500&offset=0

# %%
api_response = requests.get(api_url)
api_response
# Out:
# <Response [200]>

# %%
data = api_response.json()
data
# Out:
# {'help': 'https://data.ontario.ca/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'limit': 1500,
#   'offset': 0,
#   'records_format': 'objects',
#   'resource_id': '23172a73-7b85-49bd-9064-d600d2b21d37',
#   'total_estimation_threshold': None,
#   'records': [{'_id': 1,
#     'Sector': 'Colleges',
#     'Last name': 'Aarts',
#     'First name': 'Cheri',
#     'Salary': '$113,586.57',
#     'Benefits': '$71.01',
#     'Employer': 'Fanshawe College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 2,
#     'Sector': 'Colleges',
#     'Last name': 'Aaslepp',
#     'First name': 'Drew',
#     'Salary': '$113,685.85',
#     'Benefits': '$117.26',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 3,
#     'Sector': 'Colleges',
#     'Last name': 'Abba',
#     'First name': 'Corinne',
#     'Salary': '$102,214.17',
#     'Benefits': '$117.36',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Librarian',
#     'Year': '2020'},
#    {'_id': 4,
#     'Sector': 'Colleges',
#     'Last name': 'Abbott',
#     'First name': 'Brian',
#     'Salary': '$102,855.46',
#     'Benefits': '$117.36',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 5,
#     'Sector': 'Colleges',
#     'Last name': 'Abbott',
#     'First name': 'Kathleen',
#     'Salary': '$160,854.89',
#     'Benefits': '$326.33',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Associate Dean, Centre for Continuous Learning',
#     'Year': '2020'},
#    {'_id': 6,
#     'Sector': 'Colleges',
#     'Last name': 'Abbott',
#     'First name': 'Timothy M',
#     'Salary': '$119,452.26',
#     'Benefits': '$71.01',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 7,
#     'Sector': 'Colleges',
#     'Last name': 'Abboud',
#     'First name': 'Nadim',
#     'Salary': '$116,666.07',
#     'Benefits': '$121.14',
#     'Employer': 'Algonquin College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 8,
#     'Sector': 'Colleges',
#     'Last name': 'Abbruzzese',
#     'First name': 'Francesca',
#     'Salary': '$111,155.85',
#     'Benefits': '$75.28',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Financial and Operations Manager',
#     'Year': '2020'},
#    {'_id': 9,
#     'Sector': 'Colleges',
#     'Last name': 'Abdallah',
#     'First name': 'Mykul',
#     'Salary': '$103,042.39',
#     'Benefits': '$71.02',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 10,
#     'Sector': 'Colleges',
#     'Last name': 'Abdi',
#     'First name': 'Farhia',
#     'Salary': '$102,214.17',
#     'Benefits': '$117.36',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 11,
#     'Sector': 'Colleges',
#     'Last name': 'Abdulla',
#     'First name': 'Dalya',
#     'Salary': '$110,990.80',
#     'Benefits': '$367.36',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 12,
#     'Sector': 'Colleges',
#     'Last name': 'Abdulla',
#     'First name': 'Mouhamed',
#     'Salary': '$109,888.06',
#     'Benefits': '$367.36',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 13,
#     'Sector': 'Colleges',
#     'Last name': 'Abel',
#     'First name': 'Randy',
#     'Salary': '$108,701.18',
#     'Benefits': '$367.36',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 14,
#     'Sector': 'Colleges',
#     'Last name': 'Abesdris',
#     'First name': 'Danny',
#     'Salary': '$113,242.45',
#     'Benefits': '$117.36',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 15,
#     'Sector': 'Colleges',
#     'Last name': 'Abiscott',
#     'First name': 'Alexa',
#     'Salary': '$225,271.54',
#     'Benefits': '$78.57',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'General Counsel And Secretary of the Board of Governors',
#     'Year': '2020'},
#    {'_id': 16,
#     'Sector': 'Colleges',
#     'Last name': 'Ablarde',
#     'First name': 'Julia',
#     'Salary': '$113,680.86',
#     'Benefits': '$71.01',
#     'Employer': 'Loyalist College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 17,
#     'Sector': 'Colleges',
#     'Last name': 'Abo El Dahb',
#     'First name': 'Mona',
#     'Salary': '$101,325.30',
#     'Benefits': '$71.01',
#     'Employer': 'Fanshawe College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 18,
#     'Sector': 'Colleges',
#     'Last name': 'Abouarkoub',
#     'First name': 'Ahmed',
#     'Salary': '$120,230.80',
#     'Benefits': '$71.02',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 19,
#     'Sector': 'Colleges',
#     'Last name': 'Aboutalebi-Pour',
#     'First name': 'Hooman',
#     'Salary': '$126,140.88',
#     'Benefits': '$228.69',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Manager of Design and Construction',
#     'Year': '2020'},
#    {'_id': 20,
#     'Sector': 'Colleges',
#     'Last name': 'Abouzahra',
#     'First name': 'Mohamed',
#     'Salary': '$105,401.95',
#     'Benefits': '$71.01',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 21,
#     'Sector': 'Colleges',
#     'Last name': 'Abraham',
#     'First name': 'Dan',
#     'Salary': '$114,205.90',
#     'Benefits': '$90.10',
#     'Employer': 'Lambton College Of Applied Arts and Technology',
#     'Job title': 'Professor, Carpentry',
#     'Year': '2020'},
#    {'_id': 22,
#     'Sector': 'Colleges',
#     'Last name': 'Abraham',
#     'First name': 'Michael',
#     'Salary': '$127,705.34',
#     'Benefits': '$268.20',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Director, Instructional Technologies',
#     'Year': '2020'},
#    {'_id': 23,
#     'Sector': 'Colleges',
#     'Last name': 'Abraham',
#     'First name': 'Suzanne C',
#     'Salary': '$130,498.08',
#     'Benefits': '$274.00',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Chair',
#     'Year': '2020'},
#    {'_id': 24,
#     'Sector': 'Colleges',
#     'Last name': 'Abrahamson',
#     'First name': 'Kirsten',
#     'Salary': '$106,773.03',
#     'Benefits': '$367.36',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 25,
#     'Sector': 'Colleges',
#     'Last name': 'Absi',
#     'First name': 'Georges',
#     'Salary': '$122,804.03',
#     'Benefits': '$109.64',
#     'Employer': 'La Cité Collegiale',
#     'Job title': 'Professeur/Professor',
#     'Year': '2020'},
#    {'_id': 26,
#     'Sector': 'Colleges',
#     'Last name': 'Aburto',
#     'First name': 'Edgar L',
#     'Salary': '$107,699.11',
#     'Benefits': '$117.36',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 27,
#     'Sector': 'Colleges',
#     'Last name': 'Acciaccaferro',
#     'First name': 'Jeff',
#     'Salary': '$124,315.82',
#     'Benefits': '$76.60',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 28,
#     'Sector': 'Colleges',
#     'Last name': 'Ace',
#     'First name': 'Elen',
#     'Salary': '$113,736.56',
#     'Benefits': '$71.02',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 29,
#     'Sector': 'Colleges',
#     'Last name': 'Acharya',
#     'First name': 'Uma',
#     'Salary': '$112,524.41',
#     'Benefits': '$71.01',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 30,
#     'Sector': 'Colleges',
#     'Last name': 'Acimovic',
#     'First name': 'Dragan',
#     'Salary': '$113,005.10',
#     'Benefits': '$321.01',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 31,
#     'Sector': 'Colleges',
#     'Last name': 'Acosta',
#     'First name': 'Guillermo',
#     'Salary': '$203,646.00',
#     'Benefits': '$405.76',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Senior Dean, Faculty of Media and Creative Arts',
#     'Year': '2020'},
#    {'_id': 32,
#     'Sector': 'Colleges',
#     'Last name': 'Acosta',
#     'First name': 'Roberto',
#     'Salary': '$113,654.72',
#     'Benefits': '$117.26',
#     'Employer': 'Niagara College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 33,
#     'Sector': 'Colleges',
#     'Last name': 'Acton',
#     'First name': 'Kenneth',
#     'Salary': '$115,939.21',
#     'Benefits': '$71.02',
#     'Employer': 'St Clair College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 34,
#     'Sector': 'Colleges',
#     'Last name': 'Acton Rinaldo',
#     'First name': 'Richard',
#     'Salary': '$119,058.58',
#     'Benefits': '$117.84',
#     'Employer': 'Georgian College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 35,
#     'Sector': 'Colleges',
#     'Last name': 'Adam',
#     'First name': 'Waffa',
#     'Salary': '$113,702.12',
#     'Benefits': '$71.02',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 36,
#     'Sector': 'Colleges',
#     'Last name': 'Adams',
#     'First name': 'Christopher',
#     'Salary': '$120,919.14',
#     'Benefits': '$351.54',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Senior Collaboration Systems Architect',
#     'Year': '2020'},
#    {'_id': 37,
#     'Sector': 'Colleges',
#     'Last name': 'Adams',
#     'First name': 'Jackie',
#     'Salary': '$113,680.86',
#     'Benefits': '$71.02',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 38,
#     'Sector': 'Colleges',
#     'Last name': 'Adams',
#     'First name': 'Jodie',
#     'Salary': '$117,817.44',
#     'Benefits': '$71.02',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 39,
#     'Sector': 'Colleges',
#     'Last name': 'Adams',
#     'First name': 'Kristy',
#     'Salary': '$125,815.21',
#     'Benefits': '$71.02',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 40,
#     'Sector': 'Colleges',
#     'Last name': 'Adams',
#     'First name': 'Pamela',
#     'Salary': '$123,980.42',
#     'Benefits': '$117.26',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 41,
#     'Sector': 'Colleges',
#     'Last name': 'Adams',
#     'First name': 'Shelley',
#     'Salary': '$115,014.52',
#     'Benefits': '$86.50',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 42,
#     'Sector': 'Colleges',
#     'Last name': 'Adams',
#     'First name': 'Steffanie',
#     'Salary': '$113,184.17',
#     'Benefits': '$94.13',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 43,
#     'Sector': 'Colleges',
#     'Last name': 'Adams',
#     'First name': 'Tracey',
#     'Salary': '$113,194.88',
#     'Benefits': '$117.36',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 44,
#     'Sector': 'Colleges',
#     'Last name': 'Adams',
#     'First name': 'William',
#     'Salary': '$121,591.64',
#     'Benefits': '$71.01',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 45,
#     'Sector': 'Colleges',
#     'Last name': 'Adamson',
#     'First name': 'Cebert',
#     'Salary': '$159,008.47',
#     'Benefits': '$336.74',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Vice President, Students, International and Alumni',
#     'Year': '2020'},
#    {'_id': 46,
#     'Sector': 'Colleges',
#     'Last name': 'Adamson',
#     'First name': 'Jennifer',
#     'Salary': '$107,996.83',
#     'Benefits': '$101.12',
#     'Employer': 'Confederation College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 47,
#     'Sector': 'Colleges',
#     'Last name': 'Adamson',
#     'First name': 'Maureen',
#     'Salary': '$292,367.34',
#     'Benefits': '$10,539.06',
#     'Employer': 'Sir Sandford Fleming Of Applied Arts and Technology',
#     'Job title': 'President',
#     'Year': '2020'},
#    {'_id': 48,
#     'Sector': 'Colleges',
#     'Last name': 'Adamson',
#     'First name': 'Nancey',
#     'Salary': '$127,463.76',
#     'Benefits': '$257.76',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Human Resources Manager',
#     'Year': '2020'},
#    {'_id': 49,
#     'Sector': 'Colleges',
#     'Last name': 'Addison-Toor',
#     'First name': 'Suzanne',
#     'Salary': '$117,576.44',
#     'Benefits': '$110.48',
#     'Employer': 'Georgian College Of Applied Arts and Technology',
#     'Job title': 'Director',
#     'Year': '2020'},
#    {'_id': 50,
#     'Sector': 'Colleges',
#     'Last name': 'Adebajo',
#     'First name': 'Tunde Adeniyi',
#     'Salary': '$111,785.52',
#     'Benefits': '$117.26',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 51,
#     'Sector': 'Colleges',
#     'Last name': 'Adeeko',
#     'First name': 'Adedayo',
#     'Salary': '$118,048.82',
#     'Benefits': '$71.02',
#     'Employer': 'Sir Sandford Fleming Of Applied Arts and Technology',
#     'Job title': 'Professor, School of Health and Wellness',
#     'Year': '2020'},
#    {'_id': 52,
#     'Sector': 'Colleges',
#     'Last name': 'Adesanya',
#     'First name': 'Catherine',
#     'Salary': '$110,807.19',
#     'Benefits': '$71.02',
#     'Employer': 'Sir Sandford Fleming Of Applied Arts and Technology',
#     'Job title': 'Professor, School of Health and Wellness',
#     'Year': '2020'},
#    {'_id': 53,
#     'Sector': 'Colleges',
#     'Last name': 'Adriano',
#     'First name': 'Tony',
#     'Salary': '$103,743.02',
#     'Benefits': '$0.00',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Project Manager',
#     'Year': '2020'},
#    {'_id': 54,
#     'Sector': 'Colleges',
#     'Last name': 'Afari',
#     'First name': 'Comfort',
#     'Salary': '$113,680.74',
#     'Benefits': '$78.75',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Counsellor',
#     'Year': '2020'},
#    {'_id': 55,
#     'Sector': 'Colleges',
#     'Last name': 'Afzal',
#     'First name': 'Waqar',
#     'Salary': '$105,620.24',
#     'Benefits': '$101.56',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Decision Support Lead Analyst',
#     'Year': '2020'},
#    {'_id': 56,
#     'Sector': 'Colleges',
#     'Last name': 'Agaoglu',
#     'First name': 'Natasha',
#     'Salary': '$103,287.36',
#     'Benefits': '$108.08',
#     'Employer': 'St Lawrence College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 57,
#     'Sector': 'Colleges',
#     'Last name': 'Agate',
#     'First name': 'Jeffrey',
#     'Salary': '$138,310.50',
#     'Benefits': '$297.20',
#     'Employer': 'Algonquin College Of Applied Arts and Technology',
#     'Job title': 'Associate Director Student Support Services',
#     'Year': '2020'},
#    {'_id': 58,
#     'Sector': 'Colleges',
#     'Last name': 'Aggarwal',
#     'First name': 'Bharat',
#     'Salary': '$113,016.59',
#     'Benefits': '$321.01',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 59,
#     'Sector': 'Colleges',
#     'Last name': 'Agnew',
#     'First name': 'David',
#     'Salary': '$400,157.72',
#     'Benefits': '$17,822.32',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'President',
#     'Year': '2020'},
#    {'_id': 60,
#     'Sector': 'Colleges',
#     'Last name': 'Agnoletto',
#     'First name': 'Cinzia',
#     'Salary': '$119,675.33',
#     'Benefits': '$117.26',
#     'Employer': 'Niagara College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 61,
#     'Sector': 'Colleges',
#     'Last name': 'Aherne',
#     'First name': 'Catherine',
#     'Salary': '$109,506.82',
#     'Benefits': '$71.02',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 62,
#     'Sector': 'Colleges',
#     'Last name': 'Ahmed',
#     'First name': 'Firoz',
#     'Salary': '$117,106.20',
#     'Benefits': '$71.02',
#     'Employer': 'Lambton College Of Applied Arts and Technology',
#     'Job title': 'Professor/Coordinator, Process Piping Design',
#     'Year': '2020'},
#    {'_id': 63,
#     'Sector': 'Colleges',
#     'Last name': 'Ahmed',
#     'First name': 'Sabbir',
#     'Salary': '$110,542.44',
#     'Benefits': '$71.01',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 64,
#     'Sector': 'Colleges',
#     'Last name': 'Ahn',
#     'First name': 'Song Ho',
#     'Salary': '$120,566.31',
#     'Benefits': '$305.19',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Visualization Researcher',
#     'Year': '2020'},
#    {'_id': 65,
#     'Sector': 'Colleges',
#     'Last name': 'Aimoniotis',
#     'First name': 'Milt',
#     'Salary': '$116,171.04',
#     'Benefits': '$117.36',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor/Coordinator',
#     'Year': '2020'},
#    {'_id': 66,
#     'Sector': 'Colleges',
#     'Last name': 'Ainslie',
#     'First name': 'Elaine',
#     'Salary': '$109,370.68',
#     'Benefits': '$136.03',
#     'Employer': 'St Lawrence College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 67,
#     'Sector': 'Colleges',
#     'Last name': 'Ainsworth',
#     'First name': 'Andrew',
#     'Salary': '$134,671.11',
#     'Benefits': '$185.45',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Associate Dean',
#     'Year': '2020'},
#    {'_id': 68,
#     'Sector': 'Colleges',
#     'Last name': 'Akbari',
#     'First name': 'Emis',
#     'Salary': '$105,201.70',
#     'Benefits': '$117.36',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 69,
#     'Sector': 'Colleges',
#     'Last name': 'Akerman',
#     'First name': 'Elizabeth',
#     'Salary': '$113,184.17',
#     'Benefits': '$117.36',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 70,
#     'Sector': 'Colleges',
#     'Last name': 'Akhtari',
#     'First name': 'Ahmad',
#     'Salary': '$106,818.93',
#     'Benefits': '$321.01',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 71,
#     'Sector': 'Colleges',
#     'Last name': 'Akler',
#     'First name': 'Matthew',
#     'Salary': '$116,780.88',
#     'Benefits': '$71.02',
#     'Employer': 'Durham College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 72,
#     'Sector': 'Colleges',
#     'Last name': 'Akulick',
#     'First name': 'Hal',
#     'Salary': '$116,245.96',
#     'Benefits': '$117.36',
#     'Employer': 'Northern College Of Applied Arts and Technology',
#     'Job title': 'Professor – Computer Studies',
#     'Year': '2020'},
#    {'_id': 73,
#     'Sector': 'Colleges',
#     'Last name': 'Akyol-Yavuz',
#     'First name': 'Jansel',
#     'Salary': '$120,350.61',
#     'Benefits': '$109.87',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Senior Manager, Talent Management',
#     'Year': '2020'},
#    {'_id': 74,
#     'Sector': 'Colleges',
#     'Last name': 'Al Aubodah',
#     'First name': 'Hameed',
#     'Salary': '$116,679.78',
#     'Benefits': '$117.36',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 75,
#     'Sector': 'Colleges',
#     'Last name': 'Al Mardini',
#     'First name': 'Maisa',
#     'Salary': '$100,529.32',
#     'Benefits': '$367.36',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 76,
#     'Sector': 'Colleges',
#     'Last name': 'Al Momani',
#     'First name': 'Bilal',
#     'Salary': '$110,637.44',
#     'Benefits': '$71.02',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 77,
#     'Sector': 'Colleges',
#     'Last name': 'Al Omar',
#     'First name': 'Ruba',
#     'Salary': '$104,123.26',
#     'Benefits': '$117.26',
#     'Employer': 'Durham College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 78,
#     'Sector': 'Colleges',
#     'Last name': 'Al Salman',
#     'First name': 'Asaad',
#     'Salary': '$113,736.56',
#     'Benefits': '$117.26',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 79,
#     'Sector': 'Colleges',
#     'Last name': 'Alalibo',
#     'First name': 'Philip',
#     'Salary': '$110,700.02',
#     'Benefits': '$125.20',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 80,
#     'Sector': 'Colleges',
#     'Last name': 'Alary',
#     'First name': 'Joanne',
#     'Salary': '$114,709.49',
#     'Benefits': '$71.02',
#     'Employer': 'La Cité Collegiale',
#     'Job title': 'Professeur/Professor',
#     'Year': '2020'},
#    {'_id': 81,
#     'Sector': 'Colleges',
#     'Last name': 'Alavie',
#     'First name': 'Reza',
#     'Salary': '$113,483.19',
#     'Benefits': '$117.36',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 82,
#     'Sector': 'Colleges',
#     'Last name': 'Albarazi',
#     'First name': 'Lotfieh',
#     'Salary': '$116,009.68',
#     'Benefits': '$71.01',
#     'Employer': 'Fanshawe College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 83,
#     'Sector': 'Colleges',
#     'Last name': 'Albertini',
#     'First name': 'Lucien',
#     'Salary': '$104,655.00',
#     'Benefits': '$71.02',
#     'Employer': 'Durham College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 84,
#     'Sector': 'Colleges',
#     'Last name': 'Alberton',
#     'First name': 'Ezio',
#     'Salary': '$105,959.59',
#     'Benefits': '$117.36',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 85,
#     'Sector': 'Colleges',
#     'Last name': 'Albu',
#     'First name': 'Mihai',
#     'Salary': '$100,219.47',
#     'Benefits': '$88.06',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 86,
#     'Sector': 'Colleges',
#     'Last name': 'Alchorn',
#     'First name': 'Sheri',
#     'Salary': '$127,725.65',
#     'Benefits': '$1,897.66',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Director Planning and Resources',
#     'Year': '2020'},
#    {'_id': 87,
#     'Sector': 'Colleges',
#     'Last name': 'Aldcorn',
#     'First name': 'Jamison R',
#     'Salary': '$129,476.11',
#     'Benefits': '$71.01',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 88,
#     'Sector': 'Colleges',
#     'Last name': 'Aldea',
#     'First name': 'Daniela',
#     'Salary': '$113,736.56',
#     'Benefits': '$71.02',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 89,
#     'Sector': 'Colleges',
#     'Last name': 'Alderman',
#     'First name': 'Barbara',
#     'Salary': '$106,366.57',
#     'Benefits': '$117.26',
#     'Employer': 'St Clair College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 90,
#     'Sector': 'Colleges',
#     'Last name': 'Aleksa',
#     'First name': 'Sinisa',
#     'Salary': '$194,297.10',
#     'Benefits': '$354.36',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Chief Information Officer',
#     'Year': '2020'},
#    {'_id': 91,
#     'Sector': 'Colleges',
#     'Last name': 'Alex',
#     'First name': 'Anne',
#     'Salary': '$107,954.91',
#     'Benefits': '$71.02',
#     'Employer': 'La Cité Collegiale',
#     'Job title': 'Professeur/Professor',
#     'Year': '2020'},
#    {'_id': 92,
#     'Sector': 'Colleges',
#     'Last name': 'Alexander',
#     'First name': 'Doug',
#     'Salary': '$113,654.63',
#     'Benefits': '$121.14',
#     'Employer': 'Algonquin College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 93,
#     'Sector': 'Colleges',
#     'Last name': 'Alexander',
#     'First name': 'Gail',
#     'Salary': '$113,736.56',
#     'Benefits': '$78.66',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Librarian',
#     'Year': '2020'},
#    {'_id': 94,
#     'Sector': 'Colleges',
#     'Last name': 'Alexander',
#     'First name': 'Tamra',
#     'Salary': '$113,443.67',
#     'Benefits': '$71.02',
#     'Employer': 'Algonquin College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 95,
#     'Sector': 'Colleges',
#     'Last name': 'Ali',
#     'First name': 'Ingrid',
#     'Salary': '$110,725.98',
#     'Benefits': '$189.76',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Manager of Diversity and Inclusion',
#     'Year': '2020'},
#    {'_id': 96,
#     'Sector': 'Colleges',
#     'Last name': 'Ali',
#     'First name': 'Khalid',
#     'Salary': '$113,736.56',
#     'Benefits': '$71.02',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 97,
#     'Sector': 'Colleges',
#     'Last name': 'Ali',
#     'First name': 'Mikhail',
#     'Salary': '$114,035.90',
#     'Benefits': '$117.84',
#     'Employer': 'Georgian College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 98,
#     'Sector': 'Colleges',
#     'Last name': 'Ali',
#     'First name': 'Sabah',
#     'Salary': '$113,654.72',
#     'Benefits': '$121.14',
#     'Employer': 'Algonquin College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 99,
#     'Sector': 'Colleges',
#     'Last name': 'Ali',
#     'First name': 'Shah',
#     'Salary': '$112,344.93',
#     'Benefits': '$227.17',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Senior Human Resources Consultant',
#     'Year': '2020'},
#    {'_id': 100,
#     'Sector': 'Colleges',
#     'Last name': 'Ali',
#     'First name': 'Shirook',
#     'Salary': '$118,048.78',
#     'Benefits': '$367.36',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 101,
#     'Sector': 'Colleges',
#     'Last name': 'Allan',
#     'First name': 'Fiona',
#     'Salary': '$188,531.07',
#     'Benefits': '$2,767.66',
#     'Employer': 'Niagara College Of Applied Arts and Technology',
#     'Job title': 'Vice President, Academic',
#     'Year': '2020'},
#    {'_id': 102,
#     'Sector': 'Colleges',
#     'Last name': 'Allan',
#     'First name': 'Timothy',
#     'Salary': '$104,736.85',
#     'Benefits': '$71.02',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 103,
#     'Sector': 'Colleges',
#     'Last name': 'Allard',
#     'First name': 'Martine S',
#     'Salary': '$102,971.50',
#     'Benefits': '$180.79',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Director of English Language Institute',
#     'Year': '2020'},
#    {'_id': 104,
#     'Sector': 'Colleges',
#     'Last name': 'Allbon',
#     'First name': 'Debby',
#     'Salary': '$127,463.63',
#     'Benefits': '$112.40',
#     'Employer': 'Durham College Of Applied Arts and Technology',
#     'Job title': 'Director, Academic, Information Technology and Communications',
#     'Year': '2020'},
#    {'_id': 105,
#     'Sector': 'Colleges',
#     'Last name': 'Allen',
#     'First name': 'Dene',
#     'Salary': '$113,698.24',
#     'Benefits': '$71.02',
#     'Employer': 'Lambton College Of Applied Arts and Technology',
#     'Job title': 'Professor, Power Engineering Technology',
#     'Year': '2020'},
#    {'_id': 106,
#     'Sector': 'Colleges',
#     'Last name': 'Allen',
#     'First name': 'Dianne',
#     'Salary': '$113,680.74',
#     'Benefits': '$117.36',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 107,
#     'Sector': 'Colleges',
#     'Last name': 'Allen',
#     'First name': 'James',
#     'Salary': '$203,839.32',
#     'Benefits': '$150.66',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Associate Vice President, Information Technology',
#     'Year': '2020'},
#    {'_id': 108,
#     'Sector': 'Colleges',
#     'Last name': 'Allen',
#     'First name': 'Joelle N',
#     'Salary': '$118,942.75',
#     'Benefits': '$110.28',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Manager of Business Administration',
#     'Year': '2020'},
#    {'_id': 109,
#     'Sector': 'Colleges',
#     'Last name': 'Allen',
#     'First name': 'John',
#     'Salary': '$117,725.15',
#     'Benefits': '$117.26',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 110,
#     'Sector': 'Colleges',
#     'Last name': 'Allen',
#     'First name': 'Robert',
#     'Salary': '$117,846.08',
#     'Benefits': '$117.26',
#     'Employer': 'Sault College Of Applied Arts and Technology',
#     'Job title': 'Professor Electrical and Electronic Technologist',
#     'Year': '2020'},
#    {'_id': 111,
#     'Sector': 'Colleges',
#     'Last name': 'Allen',
#     'First name': 'Stephen',
#     'Salary': '$122,203.95',
#     'Benefits': '$109.88',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Director, English Language Centre',
#     'Year': '2020'},
#    {'_id': 112,
#     'Sector': 'Colleges',
#     'Last name': 'Alleyn',
#     'First name': 'Renee',
#     'Salary': '$103,633.79',
#     'Benefits': '$321.01',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 113,
#     'Sector': 'Colleges',
#     'Last name': 'Alleyne',
#     'First name': 'Colleen',
#     'Salary': '$116,171.04',
#     'Benefits': '$71.01',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor/Coordinator',
#     'Year': '2020'},
#    {'_id': 114,
#     'Sector': 'Colleges',
#     'Last name': 'Allidina',
#     'First name': 'Karim',
#     'Salary': '$102,593.13',
#     'Benefits': '$71.02',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 115,
#     'Sector': 'Colleges',
#     'Last name': 'Allidina',
#     'First name': 'Nazlin',
#     'Salary': '$113,184.17',
#     'Benefits': '$82.35',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 116,
#     'Sector': 'Colleges',
#     'Last name': 'Alliez',
#     'First name': 'Axel',
#     'Salary': '$113,827.72',
#     'Benefits': '$221.54',
#     'Employer': 'Collège Boréal D’Arts Appliques Et De Technologie',
#     'Job title': 'Gestionnaire, Boréal international / Manager, Boréal International',
#     'Year': '2020'},
#    {'_id': 117,
#     'Sector': 'Colleges',
#     'Last name': 'Allison',
#     'First name': 'Christopher',
#     'Salary': '$120,710.94',
#     'Benefits': '$117.36',
#     'Employer': 'Loyalist College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 118,
#     'Sector': 'Colleges',
#     'Last name': 'Allman',
#     'First name': 'James',
#     'Salary': '$101,526.39',
#     'Benefits': '$108.13',
#     'Employer': 'Cambrian College Of Applied Arts and Technology',
#     'Job title': 'Professor/Professeur',
#     'Year': '2020'},
#    {'_id': 119,
#     'Sector': 'Colleges',
#     'Last name': 'Almeida',
#     'First name': 'Janet',
#     'Salary': '$110,023.58',
#     'Benefits': '$83.93',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Associate Director, Operations',
#     'Year': '2020'},
#    {'_id': 120,
#     'Sector': 'Colleges',
#     'Last name': 'Almonte',
#     'First name': 'Richard',
#     'Salary': '$105,767.28',
#     'Benefits': '$71.01',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 121,
#     'Sector': 'Colleges',
#     'Last name': 'Almorales-Ray',
#     'First name': 'Lydia',
#     'Salary': '$105,701.24',
#     'Benefits': '$117.36',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Counsellor',
#     'Year': '2020'},
#    {'_id': 122,
#     'Sector': 'Colleges',
#     'Last name': 'Almuhtadi',
#     'First name': 'Wahab',
#     'Salary': '$116,666.07',
#     'Benefits': '$121.14',
#     'Employer': 'Algonquin College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 123,
#     'Sector': 'Colleges',
#     'Last name': 'Alnawab',
#     'First name': 'Hanadi',
#     'Salary': '$121,989.19',
#     'Benefits': '$71.02',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 124,
#     'Sector': 'Colleges',
#     'Last name': 'Aloe',
#     'First name': 'Robert',
#     'Salary': '$114,438.61',
#     'Benefits': '$71.02',
#     'Employer': 'Durham College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 125,
#     'Sector': 'Colleges',
#     'Last name': 'Alonso Facchini',
#     'First name': 'Maria Gabriela',
#     'Salary': '$108,473.23',
#     'Benefits': '$1,769.52',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Manager International Business Development And Partnerships',
#     'Year': '2020'},
#    {'_id': 126,
#     'Sector': 'Colleges',
#     'Last name': 'Alonzo',
#     'First name': 'Daniel',
#     'Salary': '$127,093.21',
#     'Benefits': '$114.40',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Associate Director, Facilities Management',
#     'Year': '2020'},
#    {'_id': 127,
#     'Sector': 'Colleges',
#     'Last name': 'Al-Rady',
#     'First name': 'Mohammad',
#     'Salary': '$117,725.07',
#     'Benefits': '$117.26',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 128,
#     'Sector': 'Colleges',
#     'Last name': 'Alrishani',
#     'First name': 'Sameer',
#     'Salary': '$113,483.19',
#     'Benefits': '$117.36',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 129,
#     'Sector': 'Colleges',
#     'Last name': 'Al-Rubaie',
#     'First name': 'Ali',
#     'Salary': '$120,074.49',
#     'Benefits': '$71.02',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 130,
#     'Sector': 'Colleges',
#     'Last name': 'Alsayyed',
#     'First name': 'Bashar',
#     'Salary': '$114,232.87',
#     'Benefits': '$228.45',
#     'Employer': 'Niagara College Of Applied Arts and Technology',
#     'Job title': 'Associate Director, Strategic Partnerships and Stakeholder Engagement',
#     'Year': '2020'},
#    {'_id': 131,
#     'Sector': 'Colleges',
#     'Last name': 'Alshami',
#     'First name': 'Mhd-Hani',
#     'Salary': '$102,902.83',
#     'Benefits': '$117.36',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 132,
#     'Sector': 'Colleges',
#     'Last name': 'Al-Shiekhly',
#     'First name': 'Abeer',
#     'Salary': '$108,624.23',
#     'Benefits': '$71.01',
#     'Employer': 'Fanshawe College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 133,
#     'Sector': 'Colleges',
#     'Last name': 'Altilia',
#     'First name': 'Carol',
#     'Salary': '$229,584.56',
#     'Benefits': '$8,011.67',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Vice President',
#     'Year': '2020'},
#    {'_id': 134,
#     'Sector': 'Colleges',
#     'Last name': 'Altoft',
#     'First name': 'Katie',
#     'Salary': '$119,675.33',
#     'Benefits': '$71.02',
#     'Employer': 'Niagara College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 135,
#     'Sector': 'Colleges',
#     'Last name': 'Altomare',
#     'First name': 'Antonio',
#     'Salary': '$104,736.85',
#     'Benefits': '$71.02',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 136,
#     'Sector': 'Colleges',
#     'Last name': 'Alubaidy',
#     'First name': 'Andy',
#     'Salary': '$116,346.57',
#     'Benefits': '$367.36',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 137,
#     'Sector': 'Colleges',
#     'Last name': 'Alvares',
#     'First name': 'Charlton',
#     'Salary': '$121,844.02',
#     'Benefits': '$71.01',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor/Coordinator',
#     'Year': '2020'},
#    {'_id': 138,
#     'Sector': 'Colleges',
#     'Last name': 'Alvarez',
#     'First name': 'Richard',
#     'Salary': '$117,873.81',
#     'Benefits': '$117.26',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 139,
#     'Sector': 'Colleges',
#     'Last name': 'Alwan',
#     'First name': 'Oruba',
#     'Salary': '$117,725.07',
#     'Benefits': '$71.02',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 140,
#     'Sector': 'Colleges',
#     'Last name': 'Al-Wazedi',
#     'First name': 'Imam',
#     'Salary': '$122,671.00',
#     'Benefits': '$117.36',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 141,
#     'Sector': 'Colleges',
#     'Last name': 'Alyea',
#     'First name': 'Lorraine',
#     'Salary': '$122,238.37',
#     'Benefits': '$367.36',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 142,
#     'Sector': 'Colleges',
#     'Last name': 'Alyman',
#     'First name': 'Shawn',
#     'Salary': '$102,938.12',
#     'Benefits': '$117.24',
#     'Employer': 'Canadore College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 143,
#     'Sector': 'Colleges',
#     'Last name': 'Amaral',
#     'First name': 'Genevieve',
#     'Salary': '$129,807.64',
#     'Benefits': '$1,923.94',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Associate Dean',
#     'Year': '2020'},
#    {'_id': 144,
#     'Sector': 'Colleges',
#     'Last name': 'Ambrose-Miller',
#     'First name': 'Carolyn',
#     'Salary': '$113,654.72',
#     'Benefits': '$117.26',
#     'Employer': 'Niagara College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 145,
#     'Sector': 'Colleges',
#     'Last name': 'Amies',
#     'First name': 'Peter B',
#     'Salary': '$113,483.19',
#     'Benefits': '$117.36',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 146,
#     'Sector': 'Colleges',
#     'Last name': 'Amirault',
#     'First name': 'Joanna',
#     'Salary': '$126,096.57',
#     'Benefits': '$113.24',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Associate Dean',
#     'Year': '2020'},
#    {'_id': 147,
#     'Sector': 'Colleges',
#     'Last name': 'Amore',
#     'First name': 'Jean-Paul',
#     'Salary': '$100,412.26',
#     'Benefits': '$0.00',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor/Principal Investigator',
#     'Year': '2020'},
#    {'_id': 148,
#     'Sector': 'Colleges',
#     'Last name': 'Amponsah',
#     'First name': 'Peter',
#     'Salary': '$127,725.57',
#     'Benefits': '$1,944.87',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Associate Dean',
#     'Year': '2020'},
#    {'_id': 149,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Angelina',
#     'Salary': '$126,484.53',
#     'Benefits': '$162.06',
#     'Employer': 'Confederation College Of Applied Arts and Technology',
#     'Job title': 'Director Dryden and Sioux Lookout Campuses',
#     'Year': '2020'},
#    {'_id': 150,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Daniel',
#     'Salary': '$115,238.29',
#     'Benefits': '$71.02',
#     'Employer': 'Algonquin College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 151,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'David K',
#     'Salary': '$113,483.19',
#     'Benefits': '$71.01',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 152,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Ian',
#     'Salary': '$113,654.72',
#     'Benefits': '$112.88',
#     'Employer': 'Algonquin College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 153,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Jacqueline',
#     'Salary': '$128,191.55',
#     'Benefits': '$114.91',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Associate Director, Student Wellness and Development',
#     'Year': '2020'},
#    {'_id': 154,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Jeffery',
#     'Salary': '$107,810.98',
#     'Benefits': '$101.54',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Aircraft Maintenance Engineer',
#     'Year': '2020'},
#    {'_id': 155,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Jeremy',
#     'Salary': '$113,654.72',
#     'Benefits': '$121.14',
#     'Employer': 'Algonquin College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 156,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Kate',
#     'Salary': '$117,725.07',
#     'Benefits': '$71.02',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 157,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Lindsay',
#     'Salary': '$130,918.52',
#     'Benefits': '$1,925.48',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Director Clinical And Experiential Learning',
#     'Year': '2020'},
#    {'_id': 158,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Michael',
#     'Salary': '$119,619.70',
#     'Benefits': '$121.14',
#     'Employer': 'Algonquin College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 159,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Michael',
#     'Salary': '$113,586.57',
#     'Benefits': '$117.37',
#     'Employer': 'Fanshawe College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 160,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Patricia',
#     'Salary': '$112,922.85',
#     'Benefits': '$108.08',
#     'Employer': 'St Lawrence College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 161,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Paula',
#     'Salary': '$112,959.17',
#     'Benefits': '$109.64',
#     'Employer': 'Sir Sandford Fleming Of Applied Arts and Technology',
#     'Job title': 'Professor, School of Environmental and Natural Resources',
#     'Year': '2020'},
#    {'_id': 162,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Richard',
#     'Salary': '$176,994.71',
#     'Benefits': '$1,365.48',
#     'Employer': 'St Lawrence College Of Applied Arts and Technology',
#     'Job title': 'Vice-President, Student Affairs',
#     'Year': '2020'},
#    {'_id': 163,
#     'Sector': 'Colleges',
#     'Last name': 'Anderson',
#     'First name': 'Stephen',
#     'Salary': '$125,107.00',
#     'Benefits': '$71.02',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 164,
#     'Sector': 'Colleges',
#     'Last name': 'Anderton',
#     'First name': 'Paula',
#     'Salary': '$106,813.63',
#     'Benefits': '$71.02',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 165,
#     'Sector': 'Colleges',
#     'Last name': 'Andrade',
#     'First name': 'John',
#     'Salary': '$117,768.28',
#     'Benefits': '$117.26',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 166,
#     'Sector': 'Colleges',
#     'Last name': 'Andreev',
#     'First name': 'Roumen',
#     'Salary': '$100,127.49',
#     'Benefits': '$55.19',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Team Lead, Development Operations',
#     'Year': '2020'},
#    {'_id': 167,
#     'Sector': 'Colleges',
#     'Last name': 'Andres',
#     'First name': 'Nitsa',
#     'Salary': '$113,586.57',
#     'Benefits': '$71.01',
#     'Employer': 'Fanshawe College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 168,
#     'Sector': 'Colleges',
#     'Last name': 'Andreucci',
#     'First name': 'John J',
#     'Salary': '$118,382.39',
#     'Benefits': '$117.36',
# ...
#     'Year': '2020'},
#    {'_id': 948,
#     'Sector': 'Colleges',
#     'Last name': 'Burrows',
#     'First name': 'Katie',
#     'Salary': '$145,611.24',
#     'Benefits': '$250.70',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Director, Development',
#     'Year': '2020'},
#    {'_id': 949,
#     'Sector': 'Colleges',
#     'Last name': 'Burrows',
#     'First name': 'Laurie',
#     'Salary': '$144,285.00',
#     'Benefits': '$128.40',
#     'Employer': 'Sault College Of Applied Arts and Technology',
#     'Job title': 'Chief Financial Officer',
#     'Year': '2020'},
#    {'_id': 950,
#     'Sector': 'Colleges',
#     'Last name': 'Burt',
#     'First name': 'Dale',
#     'Salary': '$110,643.80',
#     'Benefits': '$71.02',
#     'Employer': 'Durham College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 951,
#     'Sector': 'Colleges',
#     'Last name': 'Burt',
#     'First name': 'Edward',
#     'Salary': '$113,586.57',
#     'Benefits': '$71.01',
#     'Employer': 'Fanshawe College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 952,
#     'Sector': 'Colleges',
#     'Last name': 'Burt',
#     'First name': 'Nancy',
#     'Salary': '$109,544.04',
#     'Benefits': '$83.66',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Director, Program Review',
#     'Year': '2020'},
#    {'_id': 953,
#     'Sector': 'Colleges',
#     'Last name': 'Burtch',
#     'First name': 'Margo',
#     'Salary': '$113,782.36',
#     'Benefits': '$71.01',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 954,
#     'Sector': 'Colleges',
#     'Last name': 'Burton',
#     'First name': 'Dane',
#     'Salary': '$113,823.26',
#     'Benefits': '$35.37',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 955,
#     'Sector': 'Colleges',
#     'Last name': 'Burton',
#     'First name': 'Douglas',
#     'Salary': '$108,667.58',
#     'Benefits': '$117.84',
#     'Employer': 'Georgian College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 956,
#     'Sector': 'Colleges',
#     'Last name': 'Burton',
#     'First name': 'George',
#     'Salary': '$245,552.32',
#     'Benefits': '$359.84',
#     'Employer': 'Canadore College Of Applied Arts and Technology',
#     'Job title': 'President and Chief Executive Officer',
#     'Year': '2020'},
#    {'_id': 957,
#     'Sector': 'Colleges',
#     'Last name': 'Burton',
#     'First name': 'Jennifer',
#     'Salary': '$104,191.83',
#     'Benefits': '$74.90',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 958,
#     'Sector': 'Colleges',
#     'Last name': 'Burton',
#     'First name': 'Riley',
#     'Salary': '$126,484.53',
#     'Benefits': '$508.53',
#     'Employer': 'Confederation College Of Applied Arts and Technology',
#     'Job title': 'Associate Dean School of Business Hospitality and Media Arts',
#     'Year': '2020'},
#    {'_id': 959,
#     'Sector': 'Colleges',
#     'Last name': 'Burton',
#     'First name': 'Ronald E',
#     'Salary': '$114,465.81',
#     'Benefits': '$117.36',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 960,
#     'Sector': 'Colleges',
#     'Last name': 'Burton',
#     'First name': 'Ryan',
#     'Salary': '$179,411.54',
#     'Benefits': '$155.44',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Director, Digital Solutions',
#     'Year': '2020'},
#    {'_id': 961,
#     'Sector': 'Colleges',
#     'Last name': 'Burwash',
#     'First name': 'Robert',
#     'Salary': '$119,162.76',
#     'Benefits': '$219.69',
#     'Employer': 'Niagara College Of Applied Arts and Technology',
#     'Job title': 'Director, Human Resources',
#     'Year': '2020'},
#    {'_id': 962,
#     'Sector': 'Colleges',
#     'Last name': 'Burwell',
#     'First name': 'Patrick',
#     'Salary': '$113,611.20',
#     'Benefits': '$108.08',
#     'Employer': 'St Lawrence College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 963,
#     'Sector': 'Colleges',
#     'Last name': 'Buryta',
#     'First name': 'David',
#     'Salary': '$120,884.28',
#     'Benefits': '$71.02',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 964,
#     'Sector': 'Colleges',
#     'Last name': 'Buscaglia',
#     'First name': 'Kristen',
#     'Salary': '$113,654.72',
#     'Benefits': '$71.02',
#     'Employer': 'Niagara College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 965,
#     'Sector': 'Colleges',
#     'Last name': 'Bush',
#     'First name': 'Nancy',
#     'Salary': '$102,813.70',
#     'Benefits': '$117.24',
#     'Employer': 'Canadore College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 966,
#     'Sector': 'Colleges',
#     'Last name': 'Bush',
#     'First name': 'Susanne',
#     'Salary': '$116,679.78',
#     'Benefits': '$117.36',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 967,
#     'Sector': 'Colleges',
#     'Last name': 'Bushby',
#     'First name': 'Ruth',
#     'Salary': '$101,653.94',
#     'Benefits': '$178.14',
#     'Employer': 'Confederation College Of Applied Arts and Technology',
#     'Job title': 'Dental Clinic Administrator',
#     'Year': '2020'},
#    {'_id': 968,
#     'Sector': 'Colleges',
#     'Last name': 'Buskard',
#     'First name': 'Paula',
#     'Salary': '$115,693.93',
#     'Benefits': '$117.36',
#     'Employer': 'Loyalist College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 969,
#     'Sector': 'Colleges',
#     'Last name': 'Butko',
#     'First name': 'James',
#     'Salary': '$138,172.60',
#     'Benefits': '$269.33',
#     'Employer': 'Niagara College Of Applied Arts and Technology',
#     'Job title': 'Associate Dean, School of Liberal Studies',
#     'Year': '2020'},
#    {'_id': 970,
#     'Sector': 'Colleges',
#     'Last name': 'Butler',
#     'First name': 'Kathryn',
#     'Salary': '$113,586.57',
#     'Benefits': '$117.37',
#     'Employer': 'Fanshawe College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 971,
#     'Sector': 'Colleges',
#     'Last name': 'Butler',
#     'First name': 'Kelly',
#     'Salary': '$114,557.91',
#     'Benefits': '$90.10',
#     'Employer': 'Lambton College Of Applied Arts and Technology',
#     'Job title': 'Professor, Nursing and Personal Support Worker',
#     'Year': '2020'},
#    {'_id': 972,
#     'Sector': 'Colleges',
#     'Last name': 'Butlin',
#     'First name': 'Ruth',
#     'Salary': '$107,013.71',
#     'Benefits': '$158.80',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Director, Enterprise Applications',
#     'Year': '2020'},
#    {'_id': 973,
#     'Sector': 'Colleges',
#     'Last name': 'Butt',
#     'First name': 'Angela',
#     'Salary': '$138,156.01',
#     'Benefits': '$121.46',
#     'Employer': 'Niagara College Of Applied Arts and Technology',
#     'Job title': 'Associate Dean, School of Nursing and Personal Support Worker Studies',
#     'Year': '2020'},
#    {'_id': 974,
#     'Sector': 'Colleges',
#     'Last name': 'Butt',
#     'First name': 'Jawad',
#     'Salary': '$118,982.96',
#     'Benefits': '$117.36',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor/Coordinator',
#     'Year': '2020'},
#    {'_id': 975,
#     'Sector': 'Colleges',
#     'Last name': 'Butty',
#     'First name': 'Alexandra',
#     'Salary': '$116,039.92',
#     'Benefits': '$71.02',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 976,
#     'Sector': 'Colleges',
#     'Last name': 'Buuck',
#     'First name': 'Christine',
#     'Salary': '$203,093.04',
#     'Benefits': '$349.19',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Associate Vice President, Academic Administration and International Education',
#     'Year': '2020'},
#    {'_id': 977,
#     'Sector': 'Colleges',
#     'Last name': 'Byard',
#     'First name': 'Malcolm',
#     'Salary': '$113,736.56',
#     'Benefits': '$117.26',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 978,
#     'Sector': 'Colleges',
#     'Last name': 'Byberg',
#     'First name': 'Ann',
#     'Salary': '$105,566.72',
#     'Benefits': '$117.36',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 979,
#     'Sector': 'Colleges',
#     'Last name': 'Bychutsky',
#     'First name': 'Vadim',
#     'Salary': '$113,736.56',
#     'Benefits': '$117.26',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 980,
#     'Sector': 'Colleges',
#     'Last name': 'Byers Reid',
#     'First name': 'Tracy',
#     'Salary': '$110,603.65',
#     'Benefits': '$121.14',
#     'Employer': 'Algonquin College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 981,
#     'Sector': 'Colleges',
#     'Last name': 'Byj',
#     'First name': 'Andy',
#     'Salary': '$118,048.79',
#     'Benefits': '$367.36',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 982,
#     'Sector': 'Colleges',
#     'Last name': 'Byrd',
#     'First name': 'Lloyd ( Gerry)',
#     'Salary': '$108,507.80',
#     'Benefits': '$117.36',
#     'Employer': 'Loyalist College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 983,
#     'Sector': 'Colleges',
#     'Last name': 'Byrne',
#     'First name': 'Paul',
#     'Salary': '$113,654.72',
#     'Benefits': '$121.14',
#     'Employer': 'Algonquin College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 984,
#     'Sector': 'Colleges',
#     'Last name': 'Byrnes',
#     'First name': 'Mandy',
#     'Salary': '$110,199.20',
#     'Benefits': '$117.36',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor/Coordinator',
#     'Year': '2020'},
#    {'_id': 985,
#     'Sector': 'Colleges',
#     'Last name': 'Cable-Williams',
#     'First name': 'Beryl',
#     'Salary': '$118,048.82',
#     'Benefits': '$71.02',
#     'Employer': 'Sir Sandford Fleming Of Applied Arts and Technology',
#     'Job title': 'Professor, School of Health and Wellness',
#     'Year': '2020'},
#    {'_id': 986,
#     'Sector': 'Colleges',
#     'Last name': 'Cacciato',
#     'First name': 'Nicolo',
#     'Salary': '$116,638.74',
#     'Benefits': '$121.58',
#     'Employer': 'St Clair College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 987,
#     'Sector': 'Colleges',
#     'Last name': 'Cacciotti',
#     'First name': 'Melanie',
#     'Salary': '$102,676.34',
#     'Benefits': '$167.99',
#     'Employer': 'Cambrian College Of Applied Arts and Technology',
#     'Job title': 'Coordinator, President’s Office and Liaison to Board of Governors/Coordonnateur, bureau du président et liaison avec le conseil des gouverneurs',
#     'Year': '2020'},
#    {'_id': 988,
#     'Sector': 'Colleges',
#     'Last name': 'Cadger',
#     'First name': 'Ann',
#     'Salary': '$124,304.08',
#     'Benefits': '$321.01',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 989,
#     'Sector': 'Colleges',
#     'Last name': 'Cadieux',
#     'First name': 'Peter',
#     'Salary': '$105,625.11',
#     'Benefits': '$71.01',
#     'Employer': 'Fanshawe College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 990,
#     'Sector': 'Colleges',
#     'Last name': 'Cahuas',
#     'First name': 'Daniela',
#     'Salary': '$116,171.04',
#     'Benefits': '$71.01',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Professor/Coordinator',
#     'Year': '2020'},
#    {'_id': 991,
#     'Sector': 'Colleges',
#     'Last name': 'Cain',
#     'First name': 'Karen',
#     'Salary': '$151,193.30',
#     'Benefits': '$143.37',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Chair, Engineering and Technology',
#     'Year': '2020'},
#    {'_id': 992,
#     'Sector': 'Colleges',
#     'Last name': 'Caine',
#     'First name': 'S. Michelle',
#     'Salary': '$133,046.66',
#     'Benefits': '$130.81',
#     'Employer': 'Centennial College Of Applied Arts and Technology',
#     'Job title': 'Chair, Hospitality and Tourism',
#     'Year': '2020'},
#    {'_id': 993,
#     'Sector': 'Colleges',
#     'Last name': 'Caines',
#     'First name': 'Barbara M',
#     'Salary': '$110,498.62',
#     'Benefits': '$117.36',
#     'Employer': 'Seneca College Of Applied Arts and Technology',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 994,
#     'Sector': 'Colleges',
#     'Last name': 'Calarco',
#     'First name': 'Deborah',
#     'Salary': '$138,594.01',
#     'Benefits': '$277.42',
#     'Employer': 'Mohawk College Of Applied Arts and Technology',
#     'Job title': 'Director, Business Change Management',
#     'Year': '2020'},
#    {'_id': 995,
#     'Sector': 'Colleges',
#     'Last name': 'Caldwell',
#     'First name': 'Jeffrey',
#     'Salary': '$117,725.07',
#     'Benefits': '$117.26',
#     'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 996,
#     'Sector': 'Colleges',
#     'Last name': 'Calhoun',
#     'First name': 'Maureen',
#     'Salary': '$140,804.20',
#     'Benefits': '$179.16',
#     'Employer': 'Durham College Of Applied Arts and Technology',
#     'Job title': 'Health and Safety Officer',
#     'Year': '2020'},
#    {'_id': 997,
#     'Sector': 'Colleges',
#     'Last name': 'Callaghan',
#     'First name': 'Ann',
#     'Salary': '$124,304.26',
#     'Benefits': '$321.01',
#     'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 998,
#     'Sector': 'Colleges',
#     'Last name': 'Callaghan',
#     'First name': 'Ann',
#     'Salary': '$114,126.10',
#     'Benefits': '$117.36',
#     'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#     'Job title': 'Professor',
#     'Year': '2020'},
#    {'_id': 999,
#     'Sector': 'Colleges',
#     'Last name': 'Callender',
#     'First name': 'Joyann',
#     'Salary': '$103,206.46',
#     'Benefits': '$98.64',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Manager, Media and Student Communications',
#     'Year': '2020'},
#    {'_id': 1000,
#     'Sector': 'Colleges',
#     'Last name': 'Callirgos',
#     'First name': 'Yuri',
#     'Salary': '$148,205.04',
#     'Benefits': '$82.96',
#     'Employer': 'George Brown College Of Applied Arts and Technology',
#     'Job title': 'Administrator, Data Centre Operations',
#     'Year': '2020'},
#    ...],
#   'fields': [{'id': '_id', 'type': 'int'},
#    {'id': 'Sector', 'type': 'text'},
#    {'id': 'Last name', 'type': 'text'},
#    {'id': 'First name', 'type': 'text'},
#    {'id': 'Salary', 'type': 'text'},
#    {'id': 'Benefits', 'type': 'text'},
#    {'id': 'Employer', 'type': 'text'},
#    {'id': 'Job title', 'type': 'text'},
#    {'id': 'Year', 'type': 'text'}],
#   '_links': {'start': '/api/3/action/datastore_search?resource_id=23172a73-7b85-49bd-9064-d600d2b21d37&limit=1500',
#    'next': '/api/3/action/datastore_search?resource_id=23172a73-7b85-49bd-9064-d600d2b21d37&limit=1500&offset=1500'},
#   'total': 205855,
#   'total_was_estimated': False}}

# %%
data['result']['records']
# Out:
# [{'_id': 1,
#   'Sector': 'Colleges',
#   'Last name': 'Aarts',
#   'First name': 'Cheri',
#   'Salary': '$113,586.57',
#   'Benefits': '$71.01',
#   'Employer': 'Fanshawe College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 2,
#   'Sector': 'Colleges',
#   'Last name': 'Aaslepp',
#   'First name': 'Drew',
#   'Salary': '$113,685.85',
#   'Benefits': '$117.26',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 3,
#   'Sector': 'Colleges',
#   'Last name': 'Abba',
#   'First name': 'Corinne',
#   'Salary': '$102,214.17',
#   'Benefits': '$117.36',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Librarian',
#   'Year': '2020'},
#  {'_id': 4,
#   'Sector': 'Colleges',
#   'Last name': 'Abbott',
#   'First name': 'Brian',
#   'Salary': '$102,855.46',
#   'Benefits': '$117.36',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 5,
#   'Sector': 'Colleges',
#   'Last name': 'Abbott',
#   'First name': 'Kathleen',
#   'Salary': '$160,854.89',
#   'Benefits': '$326.33',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Associate Dean, Centre for Continuous Learning',
#   'Year': '2020'},
#  {'_id': 6,
#   'Sector': 'Colleges',
#   'Last name': 'Abbott',
#   'First name': 'Timothy M',
#   'Salary': '$119,452.26',
#   'Benefits': '$71.01',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 7,
#   'Sector': 'Colleges',
#   'Last name': 'Abboud',
#   'First name': 'Nadim',
#   'Salary': '$116,666.07',
#   'Benefits': '$121.14',
#   'Employer': 'Algonquin College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 8,
#   'Sector': 'Colleges',
#   'Last name': 'Abbruzzese',
#   'First name': 'Francesca',
#   'Salary': '$111,155.85',
#   'Benefits': '$75.28',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Financial and Operations Manager',
#   'Year': '2020'},
#  {'_id': 9,
#   'Sector': 'Colleges',
#   'Last name': 'Abdallah',
#   'First name': 'Mykul',
#   'Salary': '$103,042.39',
#   'Benefits': '$71.02',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 10,
#   'Sector': 'Colleges',
#   'Last name': 'Abdi',
#   'First name': 'Farhia',
#   'Salary': '$102,214.17',
#   'Benefits': '$117.36',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 11,
#   'Sector': 'Colleges',
#   'Last name': 'Abdulla',
#   'First name': 'Dalya',
#   'Salary': '$110,990.80',
#   'Benefits': '$367.36',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 12,
#   'Sector': 'Colleges',
#   'Last name': 'Abdulla',
#   'First name': 'Mouhamed',
#   'Salary': '$109,888.06',
#   'Benefits': '$367.36',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 13,
#   'Sector': 'Colleges',
#   'Last name': 'Abel',
#   'First name': 'Randy',
#   'Salary': '$108,701.18',
#   'Benefits': '$367.36',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 14,
#   'Sector': 'Colleges',
#   'Last name': 'Abesdris',
#   'First name': 'Danny',
#   'Salary': '$113,242.45',
#   'Benefits': '$117.36',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 15,
#   'Sector': 'Colleges',
#   'Last name': 'Abiscott',
#   'First name': 'Alexa',
#   'Salary': '$225,271.54',
#   'Benefits': '$78.57',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'General Counsel And Secretary of the Board of Governors',
#   'Year': '2020'},
#  {'_id': 16,
#   'Sector': 'Colleges',
#   'Last name': 'Ablarde',
#   'First name': 'Julia',
#   'Salary': '$113,680.86',
#   'Benefits': '$71.01',
#   'Employer': 'Loyalist College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 17,
#   'Sector': 'Colleges',
#   'Last name': 'Abo El Dahb',
#   'First name': 'Mona',
#   'Salary': '$101,325.30',
#   'Benefits': '$71.01',
#   'Employer': 'Fanshawe College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 18,
#   'Sector': 'Colleges',
#   'Last name': 'Abouarkoub',
#   'First name': 'Ahmed',
#   'Salary': '$120,230.80',
#   'Benefits': '$71.02',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 19,
#   'Sector': 'Colleges',
#   'Last name': 'Aboutalebi-Pour',
#   'First name': 'Hooman',
#   'Salary': '$126,140.88',
#   'Benefits': '$228.69',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Manager of Design and Construction',
#   'Year': '2020'},
#  {'_id': 20,
#   'Sector': 'Colleges',
#   'Last name': 'Abouzahra',
#   'First name': 'Mohamed',
#   'Salary': '$105,401.95',
#   'Benefits': '$71.01',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 21,
#   'Sector': 'Colleges',
#   'Last name': 'Abraham',
#   'First name': 'Dan',
#   'Salary': '$114,205.90',
#   'Benefits': '$90.10',
#   'Employer': 'Lambton College Of Applied Arts and Technology',
#   'Job title': 'Professor, Carpentry',
#   'Year': '2020'},
#  {'_id': 22,
#   'Sector': 'Colleges',
#   'Last name': 'Abraham',
#   'First name': 'Michael',
#   'Salary': '$127,705.34',
#   'Benefits': '$268.20',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Director, Instructional Technologies',
#   'Year': '2020'},
#  {'_id': 23,
#   'Sector': 'Colleges',
#   'Last name': 'Abraham',
#   'First name': 'Suzanne C',
#   'Salary': '$130,498.08',
#   'Benefits': '$274.00',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Chair',
#   'Year': '2020'},
#  {'_id': 24,
#   'Sector': 'Colleges',
#   'Last name': 'Abrahamson',
#   'First name': 'Kirsten',
#   'Salary': '$106,773.03',
#   'Benefits': '$367.36',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 25,
#   'Sector': 'Colleges',
#   'Last name': 'Absi',
#   'First name': 'Georges',
#   'Salary': '$122,804.03',
#   'Benefits': '$109.64',
#   'Employer': 'La Cité Collegiale',
#   'Job title': 'Professeur/Professor',
#   'Year': '2020'},
#  {'_id': 26,
#   'Sector': 'Colleges',
#   'Last name': 'Aburto',
#   'First name': 'Edgar L',
#   'Salary': '$107,699.11',
#   'Benefits': '$117.36',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 27,
#   'Sector': 'Colleges',
#   'Last name': 'Acciaccaferro',
#   'First name': 'Jeff',
#   'Salary': '$124,315.82',
#   'Benefits': '$76.60',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 28,
#   'Sector': 'Colleges',
#   'Last name': 'Ace',
#   'First name': 'Elen',
#   'Salary': '$113,736.56',
#   'Benefits': '$71.02',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 29,
#   'Sector': 'Colleges',
#   'Last name': 'Acharya',
#   'First name': 'Uma',
#   'Salary': '$112,524.41',
#   'Benefits': '$71.01',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 30,
#   'Sector': 'Colleges',
#   'Last name': 'Acimovic',
#   'First name': 'Dragan',
#   'Salary': '$113,005.10',
#   'Benefits': '$321.01',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 31,
#   'Sector': 'Colleges',
#   'Last name': 'Acosta',
#   'First name': 'Guillermo',
#   'Salary': '$203,646.00',
#   'Benefits': '$405.76',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Senior Dean, Faculty of Media and Creative Arts',
#   'Year': '2020'},
#  {'_id': 32,
#   'Sector': 'Colleges',
#   'Last name': 'Acosta',
#   'First name': 'Roberto',
#   'Salary': '$113,654.72',
#   'Benefits': '$117.26',
#   'Employer': 'Niagara College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 33,
#   'Sector': 'Colleges',
#   'Last name': 'Acton',
#   'First name': 'Kenneth',
#   'Salary': '$115,939.21',
#   'Benefits': '$71.02',
#   'Employer': 'St Clair College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 34,
#   'Sector': 'Colleges',
#   'Last name': 'Acton Rinaldo',
#   'First name': 'Richard',
#   'Salary': '$119,058.58',
#   'Benefits': '$117.84',
#   'Employer': 'Georgian College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 35,
#   'Sector': 'Colleges',
#   'Last name': 'Adam',
#   'First name': 'Waffa',
#   'Salary': '$113,702.12',
#   'Benefits': '$71.02',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 36,
#   'Sector': 'Colleges',
#   'Last name': 'Adams',
#   'First name': 'Christopher',
#   'Salary': '$120,919.14',
#   'Benefits': '$351.54',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Senior Collaboration Systems Architect',
#   'Year': '2020'},
#  {'_id': 37,
#   'Sector': 'Colleges',
#   'Last name': 'Adams',
#   'First name': 'Jackie',
#   'Salary': '$113,680.86',
#   'Benefits': '$71.02',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 38,
#   'Sector': 'Colleges',
#   'Last name': 'Adams',
#   'First name': 'Jodie',
#   'Salary': '$117,817.44',
#   'Benefits': '$71.02',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 39,
#   'Sector': 'Colleges',
#   'Last name': 'Adams',
#   'First name': 'Kristy',
#   'Salary': '$125,815.21',
#   'Benefits': '$71.02',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 40,
#   'Sector': 'Colleges',
#   'Last name': 'Adams',
#   'First name': 'Pamela',
#   'Salary': '$123,980.42',
#   'Benefits': '$117.26',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 41,
#   'Sector': 'Colleges',
#   'Last name': 'Adams',
#   'First name': 'Shelley',
#   'Salary': '$115,014.52',
#   'Benefits': '$86.50',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 42,
#   'Sector': 'Colleges',
#   'Last name': 'Adams',
#   'First name': 'Steffanie',
#   'Salary': '$113,184.17',
#   'Benefits': '$94.13',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 43,
#   'Sector': 'Colleges',
#   'Last name': 'Adams',
#   'First name': 'Tracey',
#   'Salary': '$113,194.88',
#   'Benefits': '$117.36',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 44,
#   'Sector': 'Colleges',
#   'Last name': 'Adams',
#   'First name': 'William',
#   'Salary': '$121,591.64',
#   'Benefits': '$71.01',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 45,
#   'Sector': 'Colleges',
#   'Last name': 'Adamson',
#   'First name': 'Cebert',
#   'Salary': '$159,008.47',
#   'Benefits': '$336.74',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Vice President, Students, International and Alumni',
#   'Year': '2020'},
#  {'_id': 46,
#   'Sector': 'Colleges',
#   'Last name': 'Adamson',
#   'First name': 'Jennifer',
#   'Salary': '$107,996.83',
#   'Benefits': '$101.12',
#   'Employer': 'Confederation College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 47,
#   'Sector': 'Colleges',
#   'Last name': 'Adamson',
#   'First name': 'Maureen',
#   'Salary': '$292,367.34',
#   'Benefits': '$10,539.06',
#   'Employer': 'Sir Sandford Fleming Of Applied Arts and Technology',
#   'Job title': 'President',
#   'Year': '2020'},
#  {'_id': 48,
#   'Sector': 'Colleges',
#   'Last name': 'Adamson',
#   'First name': 'Nancey',
#   'Salary': '$127,463.76',
#   'Benefits': '$257.76',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Human Resources Manager',
#   'Year': '2020'},
#  {'_id': 49,
#   'Sector': 'Colleges',
#   'Last name': 'Addison-Toor',
#   'First name': 'Suzanne',
#   'Salary': '$117,576.44',
#   'Benefits': '$110.48',
#   'Employer': 'Georgian College Of Applied Arts and Technology',
#   'Job title': 'Director',
#   'Year': '2020'},
#  {'_id': 50,
#   'Sector': 'Colleges',
#   'Last name': 'Adebajo',
#   'First name': 'Tunde Adeniyi',
#   'Salary': '$111,785.52',
#   'Benefits': '$117.26',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 51,
#   'Sector': 'Colleges',
#   'Last name': 'Adeeko',
#   'First name': 'Adedayo',
#   'Salary': '$118,048.82',
#   'Benefits': '$71.02',
#   'Employer': 'Sir Sandford Fleming Of Applied Arts and Technology',
#   'Job title': 'Professor, School of Health and Wellness',
#   'Year': '2020'},
#  {'_id': 52,
#   'Sector': 'Colleges',
#   'Last name': 'Adesanya',
#   'First name': 'Catherine',
#   'Salary': '$110,807.19',
#   'Benefits': '$71.02',
#   'Employer': 'Sir Sandford Fleming Of Applied Arts and Technology',
#   'Job title': 'Professor, School of Health and Wellness',
#   'Year': '2020'},
#  {'_id': 53,
#   'Sector': 'Colleges',
#   'Last name': 'Adriano',
#   'First name': 'Tony',
#   'Salary': '$103,743.02',
#   'Benefits': '$0.00',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Project Manager',
#   'Year': '2020'},
#  {'_id': 54,
#   'Sector': 'Colleges',
#   'Last name': 'Afari',
#   'First name': 'Comfort',
#   'Salary': '$113,680.74',
#   'Benefits': '$78.75',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Counsellor',
#   'Year': '2020'},
#  {'_id': 55,
#   'Sector': 'Colleges',
#   'Last name': 'Afzal',
#   'First name': 'Waqar',
#   'Salary': '$105,620.24',
#   'Benefits': '$101.56',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Decision Support Lead Analyst',
#   'Year': '2020'},
#  {'_id': 56,
#   'Sector': 'Colleges',
#   'Last name': 'Agaoglu',
#   'First name': 'Natasha',
#   'Salary': '$103,287.36',
#   'Benefits': '$108.08',
#   'Employer': 'St Lawrence College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 57,
#   'Sector': 'Colleges',
#   'Last name': 'Agate',
#   'First name': 'Jeffrey',
#   'Salary': '$138,310.50',
#   'Benefits': '$297.20',
#   'Employer': 'Algonquin College Of Applied Arts and Technology',
#   'Job title': 'Associate Director Student Support Services',
#   'Year': '2020'},
#  {'_id': 58,
#   'Sector': 'Colleges',
#   'Last name': 'Aggarwal',
#   'First name': 'Bharat',
#   'Salary': '$113,016.59',
#   'Benefits': '$321.01',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 59,
#   'Sector': 'Colleges',
#   'Last name': 'Agnew',
#   'First name': 'David',
#   'Salary': '$400,157.72',
#   'Benefits': '$17,822.32',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'President',
#   'Year': '2020'},
#  {'_id': 60,
#   'Sector': 'Colleges',
#   'Last name': 'Agnoletto',
#   'First name': 'Cinzia',
#   'Salary': '$119,675.33',
#   'Benefits': '$117.26',
#   'Employer': 'Niagara College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 61,
#   'Sector': 'Colleges',
#   'Last name': 'Aherne',
#   'First name': 'Catherine',
#   'Salary': '$109,506.82',
#   'Benefits': '$71.02',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 62,
#   'Sector': 'Colleges',
#   'Last name': 'Ahmed',
#   'First name': 'Firoz',
#   'Salary': '$117,106.20',
#   'Benefits': '$71.02',
#   'Employer': 'Lambton College Of Applied Arts and Technology',
#   'Job title': 'Professor/Coordinator, Process Piping Design',
#   'Year': '2020'},
#  {'_id': 63,
#   'Sector': 'Colleges',
#   'Last name': 'Ahmed',
#   'First name': 'Sabbir',
#   'Salary': '$110,542.44',
#   'Benefits': '$71.01',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 64,
#   'Sector': 'Colleges',
#   'Last name': 'Ahn',
#   'First name': 'Song Ho',
#   'Salary': '$120,566.31',
#   'Benefits': '$305.19',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Visualization Researcher',
#   'Year': '2020'},
#  {'_id': 65,
#   'Sector': 'Colleges',
#   'Last name': 'Aimoniotis',
#   'First name': 'Milt',
#   'Salary': '$116,171.04',
#   'Benefits': '$117.36',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor/Coordinator',
#   'Year': '2020'},
#  {'_id': 66,
#   'Sector': 'Colleges',
#   'Last name': 'Ainslie',
#   'First name': 'Elaine',
#   'Salary': '$109,370.68',
#   'Benefits': '$136.03',
#   'Employer': 'St Lawrence College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 67,
#   'Sector': 'Colleges',
#   'Last name': 'Ainsworth',
#   'First name': 'Andrew',
#   'Salary': '$134,671.11',
#   'Benefits': '$185.45',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Associate Dean',
#   'Year': '2020'},
#  {'_id': 68,
#   'Sector': 'Colleges',
#   'Last name': 'Akbari',
#   'First name': 'Emis',
#   'Salary': '$105,201.70',
#   'Benefits': '$117.36',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 69,
#   'Sector': 'Colleges',
#   'Last name': 'Akerman',
#   'First name': 'Elizabeth',
#   'Salary': '$113,184.17',
#   'Benefits': '$117.36',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 70,
#   'Sector': 'Colleges',
#   'Last name': 'Akhtari',
#   'First name': 'Ahmad',
#   'Salary': '$106,818.93',
#   'Benefits': '$321.01',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 71,
#   'Sector': 'Colleges',
#   'Last name': 'Akler',
#   'First name': 'Matthew',
#   'Salary': '$116,780.88',
#   'Benefits': '$71.02',
#   'Employer': 'Durham College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 72,
#   'Sector': 'Colleges',
#   'Last name': 'Akulick',
#   'First name': 'Hal',
#   'Salary': '$116,245.96',
#   'Benefits': '$117.36',
#   'Employer': 'Northern College Of Applied Arts and Technology',
#   'Job title': 'Professor – Computer Studies',
#   'Year': '2020'},
#  {'_id': 73,
#   'Sector': 'Colleges',
#   'Last name': 'Akyol-Yavuz',
#   'First name': 'Jansel',
#   'Salary': '$120,350.61',
#   'Benefits': '$109.87',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Senior Manager, Talent Management',
#   'Year': '2020'},
#  {'_id': 74,
#   'Sector': 'Colleges',
#   'Last name': 'Al Aubodah',
#   'First name': 'Hameed',
#   'Salary': '$116,679.78',
#   'Benefits': '$117.36',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 75,
#   'Sector': 'Colleges',
#   'Last name': 'Al Mardini',
#   'First name': 'Maisa',
#   'Salary': '$100,529.32',
#   'Benefits': '$367.36',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 76,
#   'Sector': 'Colleges',
#   'Last name': 'Al Momani',
#   'First name': 'Bilal',
#   'Salary': '$110,637.44',
#   'Benefits': '$71.02',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 77,
#   'Sector': 'Colleges',
#   'Last name': 'Al Omar',
#   'First name': 'Ruba',
#   'Salary': '$104,123.26',
#   'Benefits': '$117.26',
#   'Employer': 'Durham College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 78,
#   'Sector': 'Colleges',
#   'Last name': 'Al Salman',
#   'First name': 'Asaad',
#   'Salary': '$113,736.56',
#   'Benefits': '$117.26',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 79,
#   'Sector': 'Colleges',
#   'Last name': 'Alalibo',
#   'First name': 'Philip',
#   'Salary': '$110,700.02',
#   'Benefits': '$125.20',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 80,
#   'Sector': 'Colleges',
#   'Last name': 'Alary',
#   'First name': 'Joanne',
#   'Salary': '$114,709.49',
#   'Benefits': '$71.02',
#   'Employer': 'La Cité Collegiale',
#   'Job title': 'Professeur/Professor',
#   'Year': '2020'},
#  {'_id': 81,
#   'Sector': 'Colleges',
#   'Last name': 'Alavie',
#   'First name': 'Reza',
#   'Salary': '$113,483.19',
#   'Benefits': '$117.36',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 82,
#   'Sector': 'Colleges',
#   'Last name': 'Albarazi',
#   'First name': 'Lotfieh',
#   'Salary': '$116,009.68',
#   'Benefits': '$71.01',
#   'Employer': 'Fanshawe College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 83,
#   'Sector': 'Colleges',
#   'Last name': 'Albertini',
#   'First name': 'Lucien',
#   'Salary': '$104,655.00',
#   'Benefits': '$71.02',
#   'Employer': 'Durham College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 84,
#   'Sector': 'Colleges',
#   'Last name': 'Alberton',
#   'First name': 'Ezio',
#   'Salary': '$105,959.59',
#   'Benefits': '$117.36',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 85,
#   'Sector': 'Colleges',
#   'Last name': 'Albu',
#   'First name': 'Mihai',
#   'Salary': '$100,219.47',
#   'Benefits': '$88.06',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 86,
#   'Sector': 'Colleges',
#   'Last name': 'Alchorn',
#   'First name': 'Sheri',
#   'Salary': '$127,725.65',
#   'Benefits': '$1,897.66',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Director Planning and Resources',
#   'Year': '2020'},
#  {'_id': 87,
#   'Sector': 'Colleges',
#   'Last name': 'Aldcorn',
#   'First name': 'Jamison R',
#   'Salary': '$129,476.11',
#   'Benefits': '$71.01',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 88,
#   'Sector': 'Colleges',
#   'Last name': 'Aldea',
#   'First name': 'Daniela',
#   'Salary': '$113,736.56',
#   'Benefits': '$71.02',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 89,
#   'Sector': 'Colleges',
#   'Last name': 'Alderman',
#   'First name': 'Barbara',
#   'Salary': '$106,366.57',
#   'Benefits': '$117.26',
#   'Employer': 'St Clair College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 90,
#   'Sector': 'Colleges',
#   'Last name': 'Aleksa',
#   'First name': 'Sinisa',
#   'Salary': '$194,297.10',
#   'Benefits': '$354.36',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Chief Information Officer',
#   'Year': '2020'},
#  {'_id': 91,
#   'Sector': 'Colleges',
#   'Last name': 'Alex',
#   'First name': 'Anne',
#   'Salary': '$107,954.91',
#   'Benefits': '$71.02',
#   'Employer': 'La Cité Collegiale',
#   'Job title': 'Professeur/Professor',
#   'Year': '2020'},
#  {'_id': 92,
#   'Sector': 'Colleges',
#   'Last name': 'Alexander',
#   'First name': 'Doug',
#   'Salary': '$113,654.63',
#   'Benefits': '$121.14',
#   'Employer': 'Algonquin College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 93,
#   'Sector': 'Colleges',
#   'Last name': 'Alexander',
#   'First name': 'Gail',
#   'Salary': '$113,736.56',
#   'Benefits': '$78.66',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Librarian',
#   'Year': '2020'},
#  {'_id': 94,
#   'Sector': 'Colleges',
#   'Last name': 'Alexander',
#   'First name': 'Tamra',
#   'Salary': '$113,443.67',
#   'Benefits': '$71.02',
#   'Employer': 'Algonquin College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 95,
#   'Sector': 'Colleges',
#   'Last name': 'Ali',
#   'First name': 'Ingrid',
#   'Salary': '$110,725.98',
#   'Benefits': '$189.76',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Manager of Diversity and Inclusion',
#   'Year': '2020'},
#  {'_id': 96,
#   'Sector': 'Colleges',
#   'Last name': 'Ali',
#   'First name': 'Khalid',
#   'Salary': '$113,736.56',
#   'Benefits': '$71.02',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 97,
#   'Sector': 'Colleges',
#   'Last name': 'Ali',
#   'First name': 'Mikhail',
#   'Salary': '$114,035.90',
#   'Benefits': '$117.84',
#   'Employer': 'Georgian College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 98,
#   'Sector': 'Colleges',
#   'Last name': 'Ali',
#   'First name': 'Sabah',
#   'Salary': '$113,654.72',
#   'Benefits': '$121.14',
#   'Employer': 'Algonquin College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 99,
#   'Sector': 'Colleges',
#   'Last name': 'Ali',
#   'First name': 'Shah',
#   'Salary': '$112,344.93',
#   'Benefits': '$227.17',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Senior Human Resources Consultant',
#   'Year': '2020'},
#  {'_id': 100,
#   'Sector': 'Colleges',
#   'Last name': 'Ali',
#   'First name': 'Shirook',
#   'Salary': '$118,048.78',
#   'Benefits': '$367.36',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 101,
#   'Sector': 'Colleges',
#   'Last name': 'Allan',
#   'First name': 'Fiona',
#   'Salary': '$188,531.07',
#   'Benefits': '$2,767.66',
#   'Employer': 'Niagara College Of Applied Arts and Technology',
#   'Job title': 'Vice President, Academic',
#   'Year': '2020'},
#  {'_id': 102,
#   'Sector': 'Colleges',
#   'Last name': 'Allan',
#   'First name': 'Timothy',
#   'Salary': '$104,736.85',
#   'Benefits': '$71.02',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 103,
#   'Sector': 'Colleges',
#   'Last name': 'Allard',
#   'First name': 'Martine S',
#   'Salary': '$102,971.50',
#   'Benefits': '$180.79',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Director of English Language Institute',
#   'Year': '2020'},
#  {'_id': 104,
#   'Sector': 'Colleges',
#   'Last name': 'Allbon',
#   'First name': 'Debby',
#   'Salary': '$127,463.63',
#   'Benefits': '$112.40',
#   'Employer': 'Durham College Of Applied Arts and Technology',
#   'Job title': 'Director, Academic, Information Technology and Communications',
#   'Year': '2020'},
#  {'_id': 105,
#   'Sector': 'Colleges',
#   'Last name': 'Allen',
#   'First name': 'Dene',
#   'Salary': '$113,698.24',
#   'Benefits': '$71.02',
#   'Employer': 'Lambton College Of Applied Arts and Technology',
#   'Job title': 'Professor, Power Engineering Technology',
#   'Year': '2020'},
#  {'_id': 106,
#   'Sector': 'Colleges',
#   'Last name': 'Allen',
#   'First name': 'Dianne',
#   'Salary': '$113,680.74',
#   'Benefits': '$117.36',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 107,
#   'Sector': 'Colleges',
#   'Last name': 'Allen',
#   'First name': 'James',
#   'Salary': '$203,839.32',
#   'Benefits': '$150.66',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Associate Vice President, Information Technology',
#   'Year': '2020'},
#  {'_id': 108,
#   'Sector': 'Colleges',
#   'Last name': 'Allen',
#   'First name': 'Joelle N',
#   'Salary': '$118,942.75',
#   'Benefits': '$110.28',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Manager of Business Administration',
#   'Year': '2020'},
#  {'_id': 109,
#   'Sector': 'Colleges',
#   'Last name': 'Allen',
#   'First name': 'John',
#   'Salary': '$117,725.15',
#   'Benefits': '$117.26',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 110,
#   'Sector': 'Colleges',
#   'Last name': 'Allen',
#   'First name': 'Robert',
#   'Salary': '$117,846.08',
#   'Benefits': '$117.26',
#   'Employer': 'Sault College Of Applied Arts and Technology',
#   'Job title': 'Professor Electrical and Electronic Technologist',
#   'Year': '2020'},
#  {'_id': 111,
#   'Sector': 'Colleges',
#   'Last name': 'Allen',
#   'First name': 'Stephen',
#   'Salary': '$122,203.95',
#   'Benefits': '$109.88',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Director, English Language Centre',
#   'Year': '2020'},
#  {'_id': 112,
#   'Sector': 'Colleges',
#   'Last name': 'Alleyn',
#   'First name': 'Renee',
#   'Salary': '$103,633.79',
#   'Benefits': '$321.01',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 113,
#   'Sector': 'Colleges',
#   'Last name': 'Alleyne',
#   'First name': 'Colleen',
#   'Salary': '$116,171.04',
#   'Benefits': '$71.01',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor/Coordinator',
#   'Year': '2020'},
#  {'_id': 114,
#   'Sector': 'Colleges',
#   'Last name': 'Allidina',
#   'First name': 'Karim',
#   'Salary': '$102,593.13',
#   'Benefits': '$71.02',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 115,
#   'Sector': 'Colleges',
#   'Last name': 'Allidina',
#   'First name': 'Nazlin',
#   'Salary': '$113,184.17',
#   'Benefits': '$82.35',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 116,
#   'Sector': 'Colleges',
#   'Last name': 'Alliez',
#   'First name': 'Axel',
#   'Salary': '$113,827.72',
#   'Benefits': '$221.54',
#   'Employer': 'Collège Boréal D’Arts Appliques Et De Technologie',
#   'Job title': 'Gestionnaire, Boréal international / Manager, Boréal International',
#   'Year': '2020'},
#  {'_id': 117,
#   'Sector': 'Colleges',
#   'Last name': 'Allison',
#   'First name': 'Christopher',
#   'Salary': '$120,710.94',
#   'Benefits': '$117.36',
#   'Employer': 'Loyalist College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 118,
#   'Sector': 'Colleges',
#   'Last name': 'Allman',
#   'First name': 'James',
#   'Salary': '$101,526.39',
#   'Benefits': '$108.13',
#   'Employer': 'Cambrian College Of Applied Arts and Technology',
#   'Job title': 'Professor/Professeur',
#   'Year': '2020'},
#  {'_id': 119,
#   'Sector': 'Colleges',
#   'Last name': 'Almeida',
#   'First name': 'Janet',
#   'Salary': '$110,023.58',
#   'Benefits': '$83.93',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Associate Director, Operations',
#   'Year': '2020'},
#  {'_id': 120,
#   'Sector': 'Colleges',
#   'Last name': 'Almonte',
#   'First name': 'Richard',
#   'Salary': '$105,767.28',
#   'Benefits': '$71.01',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 121,
#   'Sector': 'Colleges',
#   'Last name': 'Almorales-Ray',
#   'First name': 'Lydia',
#   'Salary': '$105,701.24',
#   'Benefits': '$117.36',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Counsellor',
#   'Year': '2020'},
#  {'_id': 122,
#   'Sector': 'Colleges',
#   'Last name': 'Almuhtadi',
#   'First name': 'Wahab',
#   'Salary': '$116,666.07',
#   'Benefits': '$121.14',
#   'Employer': 'Algonquin College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 123,
#   'Sector': 'Colleges',
#   'Last name': 'Alnawab',
#   'First name': 'Hanadi',
#   'Salary': '$121,989.19',
#   'Benefits': '$71.02',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 124,
#   'Sector': 'Colleges',
#   'Last name': 'Aloe',
#   'First name': 'Robert',
#   'Salary': '$114,438.61',
#   'Benefits': '$71.02',
#   'Employer': 'Durham College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 125,
#   'Sector': 'Colleges',
#   'Last name': 'Alonso Facchini',
#   'First name': 'Maria Gabriela',
#   'Salary': '$108,473.23',
#   'Benefits': '$1,769.52',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Manager International Business Development And Partnerships',
#   'Year': '2020'},
#  {'_id': 126,
#   'Sector': 'Colleges',
#   'Last name': 'Alonzo',
#   'First name': 'Daniel',
#   'Salary': '$127,093.21',
#   'Benefits': '$114.40',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Associate Director, Facilities Management',
#   'Year': '2020'},
#  {'_id': 127,
#   'Sector': 'Colleges',
#   'Last name': 'Al-Rady',
#   'First name': 'Mohammad',
#   'Salary': '$117,725.07',
#   'Benefits': '$117.26',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 128,
#   'Sector': 'Colleges',
#   'Last name': 'Alrishani',
#   'First name': 'Sameer',
#   'Salary': '$113,483.19',
#   'Benefits': '$117.36',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 129,
#   'Sector': 'Colleges',
#   'Last name': 'Al-Rubaie',
#   'First name': 'Ali',
#   'Salary': '$120,074.49',
#   'Benefits': '$71.02',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 130,
#   'Sector': 'Colleges',
#   'Last name': 'Alsayyed',
#   'First name': 'Bashar',
#   'Salary': '$114,232.87',
#   'Benefits': '$228.45',
#   'Employer': 'Niagara College Of Applied Arts and Technology',
#   'Job title': 'Associate Director, Strategic Partnerships and Stakeholder Engagement',
#   'Year': '2020'},
#  {'_id': 131,
#   'Sector': 'Colleges',
#   'Last name': 'Alshami',
#   'First name': 'Mhd-Hani',
#   'Salary': '$102,902.83',
#   'Benefits': '$117.36',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 132,
#   'Sector': 'Colleges',
#   'Last name': 'Al-Shiekhly',
#   'First name': 'Abeer',
#   'Salary': '$108,624.23',
#   'Benefits': '$71.01',
#   'Employer': 'Fanshawe College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 133,
#   'Sector': 'Colleges',
#   'Last name': 'Altilia',
#   'First name': 'Carol',
#   'Salary': '$229,584.56',
#   'Benefits': '$8,011.67',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Vice President',
#   'Year': '2020'},
#  {'_id': 134,
#   'Sector': 'Colleges',
#   'Last name': 'Altoft',
#   'First name': 'Katie',
#   'Salary': '$119,675.33',
#   'Benefits': '$71.02',
#   'Employer': 'Niagara College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 135,
#   'Sector': 'Colleges',
#   'Last name': 'Altomare',
#   'First name': 'Antonio',
#   'Salary': '$104,736.85',
#   'Benefits': '$71.02',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 136,
#   'Sector': 'Colleges',
#   'Last name': 'Alubaidy',
#   'First name': 'Andy',
#   'Salary': '$116,346.57',
#   'Benefits': '$367.36',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 137,
#   'Sector': 'Colleges',
#   'Last name': 'Alvares',
#   'First name': 'Charlton',
#   'Salary': '$121,844.02',
#   'Benefits': '$71.01',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor/Coordinator',
#   'Year': '2020'},
#  {'_id': 138,
#   'Sector': 'Colleges',
#   'Last name': 'Alvarez',
#   'First name': 'Richard',
#   'Salary': '$117,873.81',
#   'Benefits': '$117.26',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 139,
#   'Sector': 'Colleges',
#   'Last name': 'Alwan',
#   'First name': 'Oruba',
#   'Salary': '$117,725.07',
#   'Benefits': '$71.02',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 140,
#   'Sector': 'Colleges',
#   'Last name': 'Al-Wazedi',
#   'First name': 'Imam',
#   'Salary': '$122,671.00',
#   'Benefits': '$117.36',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 141,
#   'Sector': 'Colleges',
#   'Last name': 'Alyea',
#   'First name': 'Lorraine',
#   'Salary': '$122,238.37',
#   'Benefits': '$367.36',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 142,
#   'Sector': 'Colleges',
#   'Last name': 'Alyman',
#   'First name': 'Shawn',
#   'Salary': '$102,938.12',
#   'Benefits': '$117.24',
#   'Employer': 'Canadore College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 143,
#   'Sector': 'Colleges',
#   'Last name': 'Amaral',
#   'First name': 'Genevieve',
#   'Salary': '$129,807.64',
#   'Benefits': '$1,923.94',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Associate Dean',
#   'Year': '2020'},
#  {'_id': 144,
#   'Sector': 'Colleges',
#   'Last name': 'Ambrose-Miller',
#   'First name': 'Carolyn',
#   'Salary': '$113,654.72',
#   'Benefits': '$117.26',
#   'Employer': 'Niagara College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 145,
#   'Sector': 'Colleges',
#   'Last name': 'Amies',
#   'First name': 'Peter B',
#   'Salary': '$113,483.19',
#   'Benefits': '$117.36',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 146,
#   'Sector': 'Colleges',
#   'Last name': 'Amirault',
#   'First name': 'Joanna',
#   'Salary': '$126,096.57',
#   'Benefits': '$113.24',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Associate Dean',
#   'Year': '2020'},
#  {'_id': 147,
#   'Sector': 'Colleges',
#   'Last name': 'Amore',
#   'First name': 'Jean-Paul',
#   'Salary': '$100,412.26',
#   'Benefits': '$0.00',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor/Principal Investigator',
#   'Year': '2020'},
#  {'_id': 148,
#   'Sector': 'Colleges',
#   'Last name': 'Amponsah',
#   'First name': 'Peter',
#   'Salary': '$127,725.57',
#   'Benefits': '$1,944.87',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Associate Dean',
#   'Year': '2020'},
#  {'_id': 149,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Angelina',
#   'Salary': '$126,484.53',
#   'Benefits': '$162.06',
#   'Employer': 'Confederation College Of Applied Arts and Technology',
#   'Job title': 'Director Dryden and Sioux Lookout Campuses',
#   'Year': '2020'},
#  {'_id': 150,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Daniel',
#   'Salary': '$115,238.29',
#   'Benefits': '$71.02',
#   'Employer': 'Algonquin College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 151,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'David K',
#   'Salary': '$113,483.19',
#   'Benefits': '$71.01',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 152,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Ian',
#   'Salary': '$113,654.72',
#   'Benefits': '$112.88',
#   'Employer': 'Algonquin College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 153,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Jacqueline',
#   'Salary': '$128,191.55',
#   'Benefits': '$114.91',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Associate Director, Student Wellness and Development',
#   'Year': '2020'},
#  {'_id': 154,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Jeffery',
#   'Salary': '$107,810.98',
#   'Benefits': '$101.54',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Aircraft Maintenance Engineer',
#   'Year': '2020'},
#  {'_id': 155,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Jeremy',
#   'Salary': '$113,654.72',
#   'Benefits': '$121.14',
#   'Employer': 'Algonquin College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 156,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Kate',
#   'Salary': '$117,725.07',
#   'Benefits': '$71.02',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 157,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Lindsay',
#   'Salary': '$130,918.52',
#   'Benefits': '$1,925.48',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Director Clinical And Experiential Learning',
#   'Year': '2020'},
#  {'_id': 158,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Michael',
#   'Salary': '$119,619.70',
#   'Benefits': '$121.14',
#   'Employer': 'Algonquin College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 159,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Michael',
#   'Salary': '$113,586.57',
#   'Benefits': '$117.37',
#   'Employer': 'Fanshawe College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 160,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Patricia',
#   'Salary': '$112,922.85',
#   'Benefits': '$108.08',
#   'Employer': 'St Lawrence College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 161,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Paula',
#   'Salary': '$112,959.17',
#   'Benefits': '$109.64',
#   'Employer': 'Sir Sandford Fleming Of Applied Arts and Technology',
#   'Job title': 'Professor, School of Environmental and Natural Resources',
#   'Year': '2020'},
#  {'_id': 162,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Richard',
#   'Salary': '$176,994.71',
#   'Benefits': '$1,365.48',
#   'Employer': 'St Lawrence College Of Applied Arts and Technology',
#   'Job title': 'Vice-President, Student Affairs',
#   'Year': '2020'},
#  {'_id': 163,
#   'Sector': 'Colleges',
#   'Last name': 'Anderson',
#   'First name': 'Stephen',
#   'Salary': '$125,107.00',
#   'Benefits': '$71.02',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 164,
#   'Sector': 'Colleges',
#   'Last name': 'Anderton',
#   'First name': 'Paula',
#   'Salary': '$106,813.63',
#   'Benefits': '$71.02',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 165,
#   'Sector': 'Colleges',
#   'Last name': 'Andrade',
#   'First name': 'John',
#   'Salary': '$117,768.28',
#   'Benefits': '$117.26',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 166,
#   'Sector': 'Colleges',
#   'Last name': 'Andreev',
#   'First name': 'Roumen',
#   'Salary': '$100,127.49',
#   'Benefits': '$55.19',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Team Lead, Development Operations',
#   'Year': '2020'},
#  {'_id': 167,
#   'Sector': 'Colleges',
#   'Last name': 'Andres',
#   'First name': 'Nitsa',
#   'Salary': '$113,586.57',
#   'Benefits': '$71.01',
#   'Employer': 'Fanshawe College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 168,
#   'Sector': 'Colleges',
#   'Last name': 'Andreucci',
#   'First name': 'John J',
#   'Salary': '$118,382.39',
#   'Benefits': '$117.36',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 169,
#   'Sector': 'Colleges',
#   'Last name': 'Andrew',
#   'First name': 'Rhett',
#   'Salary': '$114,841.73',
#   'Benefits': '$117.26',
#   'Employer': 'Sault College Of Applied Arts and Technology',
#   'Job title': 'Professor Communications',
#   'Year': '2020'},
#  {'_id': 170,
#   'Sector': 'Colleges',
#   'Last name': 'Andrews',
#   'First name': 'Barry',
#   'Salary': '$102,703.10',
#   'Benefits': '$65.34',
#   'Employer': 'St Lawrence College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 171,
#   'Sector': 'Colleges',
#   'Last name': 'Andrews',
#   'First name': 'Greg',
#   'Salary': '$120,751.79',
#   'Benefits': '$321.01',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 172,
#   'Sector': 'Colleges',
#   'Last name': 'Andrews',
#   'First name': 'Joe',
#   'Salary': '$160,746.16',
#   'Benefits': '$265.52',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Director, Orangeville Campus',
#   'Year': '2020'},
#  {'_id': 173,
#   'Sector': 'Colleges',
#   'Last name': 'Andrews',
#   'First name': 'Stacey',
#   'Salary': '$125,482.21',
#   'Benefits': '$118.80',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Senior Manager, Public Safety and Security',
#   'Year': '2020'},
#  {'_id': 174,
#   'Sector': 'Colleges',
#   'Last name': 'Andrianopoulos',
#   'First name': 'Joanne',
#   'Salary': '$107,512.19',
#   'Benefits': '$117.36',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 175,
#   'Sector': 'Colleges',
#   'Last name': 'Andrusak',
#   'First name': 'Wendy',
#   'Salary': '$114,089.27',
#   'Benefits': '$71.01',
#   'Employer': 'Fanshawe College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 176,
#   'Sector': 'Colleges',
#   'Last name': 'Andrushak',
#   'First name': 'Steven',
#   'Salary': '$122,600.44',
#   'Benefits': '$71.01',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 177,
#   'Sector': 'Colleges',
#   'Last name': 'Angelakos',
#   'First name': 'Bill',
#   'Salary': '$168,697.61',
#   'Benefits': '$216.44',
#   'Employer': 'Georgian College Of Applied Arts and Technology',
#   'Job title': 'Dean',
#   'Year': '2020'},
#  {'_id': 178,
#   'Sector': 'Colleges',
#   'Last name': 'Angelakos',
#   'First name': 'Dino',
#   'Salary': '$122,872.04',
#   'Benefits': '$71.02',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 179,
#   'Sector': 'Colleges',
#   'Last name': 'Angelini',
#   'First name': 'Paul',
#   'Salary': '$122,717.66',
#   'Benefits': '$321.01',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 180,
#   'Sector': 'Colleges',
#   'Last name': 'Angius',
#   'First name': 'Claudio',
#   'Salary': '$113,654.72',
#   'Benefits': '$117.26',
#   'Employer': 'Niagara College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 181,
#   'Sector': 'Colleges',
#   'Last name': 'Angle',
#   'First name': 'Dennis',
# ...
#   'Year': '2020'},
#  {'_id': 942,
#   'Sector': 'Colleges',
#   'Last name': 'Burns',
#   'First name': 'Cheryl',
#   'Salary': '$125,486.22',
#   'Benefits': '$116.22',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Associate Dean, Social Services and Justice Studies',
#   'Year': '2020'},
#  {'_id': 943,
#   'Sector': 'Colleges',
#   'Last name': 'Burns',
#   'First name': 'Christina',
#   'Salary': '$105,174.52',
#   'Benefits': '$117.36',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 944,
#   'Sector': 'Colleges',
#   'Last name': 'Burns',
#   'First name': 'Patricia',
#   'Salary': '$159,657.21',
#   'Benefits': '$2,139.86',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Associate Dean',
#   'Year': '2020'},
#  {'_id': 945,
#   'Sector': 'Colleges',
#   'Last name': 'Burns',
#   'First name': 'Rhonda',
#   'Salary': '$114,636.56',
#   'Benefits': '$71.02',
#   'Employer': 'Niagara College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 946,
#   'Sector': 'Colleges',
#   'Last name': 'Burns',
#   'First name': 'Treena',
#   'Salary': '$115,721.53',
#   'Benefits': '$71.01',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 947,
#   'Sector': 'Colleges',
#   'Last name': 'Burpee',
#   'First name': 'Katharine',
#   'Salary': '$152,816.71',
#   'Benefits': '$143.62',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Director, Learning and Resource Centres',
#   'Year': '2020'},
#  {'_id': 948,
#   'Sector': 'Colleges',
#   'Last name': 'Burrows',
#   'First name': 'Katie',
#   'Salary': '$145,611.24',
#   'Benefits': '$250.70',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Director, Development',
#   'Year': '2020'},
#  {'_id': 949,
#   'Sector': 'Colleges',
#   'Last name': 'Burrows',
#   'First name': 'Laurie',
#   'Salary': '$144,285.00',
#   'Benefits': '$128.40',
#   'Employer': 'Sault College Of Applied Arts and Technology',
#   'Job title': 'Chief Financial Officer',
#   'Year': '2020'},
#  {'_id': 950,
#   'Sector': 'Colleges',
#   'Last name': 'Burt',
#   'First name': 'Dale',
#   'Salary': '$110,643.80',
#   'Benefits': '$71.02',
#   'Employer': 'Durham College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 951,
#   'Sector': 'Colleges',
#   'Last name': 'Burt',
#   'First name': 'Edward',
#   'Salary': '$113,586.57',
#   'Benefits': '$71.01',
#   'Employer': 'Fanshawe College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 952,
#   'Sector': 'Colleges',
#   'Last name': 'Burt',
#   'First name': 'Nancy',
#   'Salary': '$109,544.04',
#   'Benefits': '$83.66',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Director, Program Review',
#   'Year': '2020'},
#  {'_id': 953,
#   'Sector': 'Colleges',
#   'Last name': 'Burtch',
#   'First name': 'Margo',
#   'Salary': '$113,782.36',
#   'Benefits': '$71.01',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 954,
#   'Sector': 'Colleges',
#   'Last name': 'Burton',
#   'First name': 'Dane',
#   'Salary': '$113,823.26',
#   'Benefits': '$35.37',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 955,
#   'Sector': 'Colleges',
#   'Last name': 'Burton',
#   'First name': 'Douglas',
#   'Salary': '$108,667.58',
#   'Benefits': '$117.84',
#   'Employer': 'Georgian College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 956,
#   'Sector': 'Colleges',
#   'Last name': 'Burton',
#   'First name': 'George',
#   'Salary': '$245,552.32',
#   'Benefits': '$359.84',
#   'Employer': 'Canadore College Of Applied Arts and Technology',
#   'Job title': 'President and Chief Executive Officer',
#   'Year': '2020'},
#  {'_id': 957,
#   'Sector': 'Colleges',
#   'Last name': 'Burton',
#   'First name': 'Jennifer',
#   'Salary': '$104,191.83',
#   'Benefits': '$74.90',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 958,
#   'Sector': 'Colleges',
#   'Last name': 'Burton',
#   'First name': 'Riley',
#   'Salary': '$126,484.53',
#   'Benefits': '$508.53',
#   'Employer': 'Confederation College Of Applied Arts and Technology',
#   'Job title': 'Associate Dean School of Business Hospitality and Media Arts',
#   'Year': '2020'},
#  {'_id': 959,
#   'Sector': 'Colleges',
#   'Last name': 'Burton',
#   'First name': 'Ronald E',
#   'Salary': '$114,465.81',
#   'Benefits': '$117.36',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 960,
#   'Sector': 'Colleges',
#   'Last name': 'Burton',
#   'First name': 'Ryan',
#   'Salary': '$179,411.54',
#   'Benefits': '$155.44',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Director, Digital Solutions',
#   'Year': '2020'},
#  {'_id': 961,
#   'Sector': 'Colleges',
#   'Last name': 'Burwash',
#   'First name': 'Robert',
#   'Salary': '$119,162.76',
#   'Benefits': '$219.69',
#   'Employer': 'Niagara College Of Applied Arts and Technology',
#   'Job title': 'Director, Human Resources',
#   'Year': '2020'},
#  {'_id': 962,
#   'Sector': 'Colleges',
#   'Last name': 'Burwell',
#   'First name': 'Patrick',
#   'Salary': '$113,611.20',
#   'Benefits': '$108.08',
#   'Employer': 'St Lawrence College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 963,
#   'Sector': 'Colleges',
#   'Last name': 'Buryta',
#   'First name': 'David',
#   'Salary': '$120,884.28',
#   'Benefits': '$71.02',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 964,
#   'Sector': 'Colleges',
#   'Last name': 'Buscaglia',
#   'First name': 'Kristen',
#   'Salary': '$113,654.72',
#   'Benefits': '$71.02',
#   'Employer': 'Niagara College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 965,
#   'Sector': 'Colleges',
#   'Last name': 'Bush',
#   'First name': 'Nancy',
#   'Salary': '$102,813.70',
#   'Benefits': '$117.24',
#   'Employer': 'Canadore College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 966,
#   'Sector': 'Colleges',
#   'Last name': 'Bush',
#   'First name': 'Susanne',
#   'Salary': '$116,679.78',
#   'Benefits': '$117.36',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 967,
#   'Sector': 'Colleges',
#   'Last name': 'Bushby',
#   'First name': 'Ruth',
#   'Salary': '$101,653.94',
#   'Benefits': '$178.14',
#   'Employer': 'Confederation College Of Applied Arts and Technology',
#   'Job title': 'Dental Clinic Administrator',
#   'Year': '2020'},
#  {'_id': 968,
#   'Sector': 'Colleges',
#   'Last name': 'Buskard',
#   'First name': 'Paula',
#   'Salary': '$115,693.93',
#   'Benefits': '$117.36',
#   'Employer': 'Loyalist College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 969,
#   'Sector': 'Colleges',
#   'Last name': 'Butko',
#   'First name': 'James',
#   'Salary': '$138,172.60',
#   'Benefits': '$269.33',
#   'Employer': 'Niagara College Of Applied Arts and Technology',
#   'Job title': 'Associate Dean, School of Liberal Studies',
#   'Year': '2020'},
#  {'_id': 970,
#   'Sector': 'Colleges',
#   'Last name': 'Butler',
#   'First name': 'Kathryn',
#   'Salary': '$113,586.57',
#   'Benefits': '$117.37',
#   'Employer': 'Fanshawe College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 971,
#   'Sector': 'Colleges',
#   'Last name': 'Butler',
#   'First name': 'Kelly',
#   'Salary': '$114,557.91',
#   'Benefits': '$90.10',
#   'Employer': 'Lambton College Of Applied Arts and Technology',
#   'Job title': 'Professor, Nursing and Personal Support Worker',
#   'Year': '2020'},
#  {'_id': 972,
#   'Sector': 'Colleges',
#   'Last name': 'Butlin',
#   'First name': 'Ruth',
#   'Salary': '$107,013.71',
#   'Benefits': '$158.80',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Director, Enterprise Applications',
#   'Year': '2020'},
#  {'_id': 973,
#   'Sector': 'Colleges',
#   'Last name': 'Butt',
#   'First name': 'Angela',
#   'Salary': '$138,156.01',
#   'Benefits': '$121.46',
#   'Employer': 'Niagara College Of Applied Arts and Technology',
#   'Job title': 'Associate Dean, School of Nursing and Personal Support Worker Studies',
#   'Year': '2020'},
#  {'_id': 974,
#   'Sector': 'Colleges',
#   'Last name': 'Butt',
#   'First name': 'Jawad',
#   'Salary': '$118,982.96',
#   'Benefits': '$117.36',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor/Coordinator',
#   'Year': '2020'},
#  {'_id': 975,
#   'Sector': 'Colleges',
#   'Last name': 'Butty',
#   'First name': 'Alexandra',
#   'Salary': '$116,039.92',
#   'Benefits': '$71.02',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 976,
#   'Sector': 'Colleges',
#   'Last name': 'Buuck',
#   'First name': 'Christine',
#   'Salary': '$203,093.04',
#   'Benefits': '$349.19',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Associate Vice President, Academic Administration and International Education',
#   'Year': '2020'},
#  {'_id': 977,
#   'Sector': 'Colleges',
#   'Last name': 'Byard',
#   'First name': 'Malcolm',
#   'Salary': '$113,736.56',
#   'Benefits': '$117.26',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 978,
#   'Sector': 'Colleges',
#   'Last name': 'Byberg',
#   'First name': 'Ann',
#   'Salary': '$105,566.72',
#   'Benefits': '$117.36',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 979,
#   'Sector': 'Colleges',
#   'Last name': 'Bychutsky',
#   'First name': 'Vadim',
#   'Salary': '$113,736.56',
#   'Benefits': '$117.26',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 980,
#   'Sector': 'Colleges',
#   'Last name': 'Byers Reid',
#   'First name': 'Tracy',
#   'Salary': '$110,603.65',
#   'Benefits': '$121.14',
#   'Employer': 'Algonquin College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 981,
#   'Sector': 'Colleges',
#   'Last name': 'Byj',
#   'First name': 'Andy',
#   'Salary': '$118,048.79',
#   'Benefits': '$367.36',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 982,
#   'Sector': 'Colleges',
#   'Last name': 'Byrd',
#   'First name': 'Lloyd ( Gerry)',
#   'Salary': '$108,507.80',
#   'Benefits': '$117.36',
#   'Employer': 'Loyalist College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 983,
#   'Sector': 'Colleges',
#   'Last name': 'Byrne',
#   'First name': 'Paul',
#   'Salary': '$113,654.72',
#   'Benefits': '$121.14',
#   'Employer': 'Algonquin College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 984,
#   'Sector': 'Colleges',
#   'Last name': 'Byrnes',
#   'First name': 'Mandy',
#   'Salary': '$110,199.20',
#   'Benefits': '$117.36',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor/Coordinator',
#   'Year': '2020'},
#  {'_id': 985,
#   'Sector': 'Colleges',
#   'Last name': 'Cable-Williams',
#   'First name': 'Beryl',
#   'Salary': '$118,048.82',
#   'Benefits': '$71.02',
#   'Employer': 'Sir Sandford Fleming Of Applied Arts and Technology',
#   'Job title': 'Professor, School of Health and Wellness',
#   'Year': '2020'},
#  {'_id': 986,
#   'Sector': 'Colleges',
#   'Last name': 'Cacciato',
#   'First name': 'Nicolo',
#   'Salary': '$116,638.74',
#   'Benefits': '$121.58',
#   'Employer': 'St Clair College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 987,
#   'Sector': 'Colleges',
#   'Last name': 'Cacciotti',
#   'First name': 'Melanie',
#   'Salary': '$102,676.34',
#   'Benefits': '$167.99',
#   'Employer': 'Cambrian College Of Applied Arts and Technology',
#   'Job title': 'Coordinator, President’s Office and Liaison to Board of Governors/Coordonnateur, bureau du président et liaison avec le conseil des gouverneurs',
#   'Year': '2020'},
#  {'_id': 988,
#   'Sector': 'Colleges',
#   'Last name': 'Cadger',
#   'First name': 'Ann',
#   'Salary': '$124,304.08',
#   'Benefits': '$321.01',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 989,
#   'Sector': 'Colleges',
#   'Last name': 'Cadieux',
#   'First name': 'Peter',
#   'Salary': '$105,625.11',
#   'Benefits': '$71.01',
#   'Employer': 'Fanshawe College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 990,
#   'Sector': 'Colleges',
#   'Last name': 'Cahuas',
#   'First name': 'Daniela',
#   'Salary': '$116,171.04',
#   'Benefits': '$71.01',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Professor/Coordinator',
#   'Year': '2020'},
#  {'_id': 991,
#   'Sector': 'Colleges',
#   'Last name': 'Cain',
#   'First name': 'Karen',
#   'Salary': '$151,193.30',
#   'Benefits': '$143.37',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Chair, Engineering and Technology',
#   'Year': '2020'},
#  {'_id': 992,
#   'Sector': 'Colleges',
#   'Last name': 'Caine',
#   'First name': 'S. Michelle',
#   'Salary': '$133,046.66',
#   'Benefits': '$130.81',
#   'Employer': 'Centennial College Of Applied Arts and Technology',
#   'Job title': 'Chair, Hospitality and Tourism',
#   'Year': '2020'},
#  {'_id': 993,
#   'Sector': 'Colleges',
#   'Last name': 'Caines',
#   'First name': 'Barbara M',
#   'Salary': '$110,498.62',
#   'Benefits': '$117.36',
#   'Employer': 'Seneca College Of Applied Arts and Technology',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 994,
#   'Sector': 'Colleges',
#   'Last name': 'Calarco',
#   'First name': 'Deborah',
#   'Salary': '$138,594.01',
#   'Benefits': '$277.42',
#   'Employer': 'Mohawk College Of Applied Arts and Technology',
#   'Job title': 'Director, Business Change Management',
#   'Year': '2020'},
#  {'_id': 995,
#   'Sector': 'Colleges',
#   'Last name': 'Caldwell',
#   'First name': 'Jeffrey',
#   'Salary': '$117,725.07',
#   'Benefits': '$117.26',
#   'Employer': 'Humber College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 996,
#   'Sector': 'Colleges',
#   'Last name': 'Calhoun',
#   'First name': 'Maureen',
#   'Salary': '$140,804.20',
#   'Benefits': '$179.16',
#   'Employer': 'Durham College Of Applied Arts and Technology',
#   'Job title': 'Health and Safety Officer',
#   'Year': '2020'},
#  {'_id': 997,
#   'Sector': 'Colleges',
#   'Last name': 'Callaghan',
#   'First name': 'Ann',
#   'Salary': '$124,304.26',
#   'Benefits': '$321.01',
#   'Employer': 'Sheridan College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 998,
#   'Sector': 'Colleges',
#   'Last name': 'Callaghan',
#   'First name': 'Ann',
#   'Salary': '$114,126.10',
#   'Benefits': '$117.36',
#   'Employer': 'Conestoga College Institute Of Technology and Advanced Learning',
#   'Job title': 'Professor',
#   'Year': '2020'},
#  {'_id': 999,
#   'Sector': 'Colleges',
#   'Last name': 'Callender',
#   'First name': 'Joyann',
#   'Salary': '$103,206.46',
#   'Benefits': '$98.64',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Manager, Media and Student Communications',
#   'Year': '2020'},
#  {'_id': 1000,
#   'Sector': 'Colleges',
#   'Last name': 'Callirgos',
#   'First name': 'Yuri',
#   'Salary': '$148,205.04',
#   'Benefits': '$82.96',
#   'Employer': 'George Brown College Of Applied Arts and Technology',
#   'Job title': 'Administrator, Data Centre Operations',
#   'Year': '2020'},
#  ...]

# %%
salary_data = pd.DataFrame(data['result']['records'])
salary_data
# Out:
#        _id    Sector   Last name First name       Salary   Benefits
# 0        1  Colleges       Aarts      Cheri  $113,586.57     $71.01  \
# 1        2  Colleges     Aaslepp       Drew  $113,685.85    $117.26
# 2        3  Colleges        Abba    Corinne  $102,214.17    $117.36
# 3        4  Colleges      Abbott      Brian  $102,855.46    $117.36
# 4        5  Colleges      Abbott   Kathleen  $160,854.89    $326.33
# ...    ...       ...         ...        ...          ...        ...
# 1495  1496  Colleges  Cunningham       John  $113,035.90    $117.84
# 1496  1497  Colleges  Cunningham      Leigh  $108,974.47  $1,209.56
# 1497  1498  Colleges  Cunningham   Marianne  $104,251.26    $216.11
# 1498  1499  Colleges      Cupido    Anthony  $138,634.58    $279.74
# 1499  1500  Colleges      Cupido       June  $154,106.28    $114.37
#
#                                                Employer
# 0       Fanshawe College Of Applied Arts and Technology  \
# 1     Humber College Institute Of Technology and Adv...
# 2     George Brown College Of Applied Arts and Techn...
# 3     Conestoga College Institute Of Technology and ...
# 4     George Brown College Of Applied Arts and Techn...
# ...                                                 ...
# 1495    Georgian College Of Applied Arts and Technology
# 1496  St Lawrence College Of Applied Arts and Techno...
# 1497      Seneca College Of Applied Arts and Technology
# 1498      Mohawk College Of Applied Arts and Technology
# 1499  Sheridan College Institute Of Technology and A...
#
#                                               Job title  Year
# 0                                             Professor  2020
# 1                                             Professor  2020
# 2                                             Librarian  2020
# 3                                             Professor  2020
# 4        Associate Dean, Centre for Continuous Learning  2020
# ...                                                 ...   ...
# 1495                                          Professor  2020
# 1496  Associate Director, Libraries and Student Success  2020
# 1497            Manager of Disability and Accommodation  2020
# 1498                     Research Chair, Sustainability  2020
# 1499                                Associate Registrar  2020
#
# [1500 rows x 9 columns]

# %%
null_counts = salary_data.isnull().sum()
print(null_counts)
# Out:
# _id           0
# Sector        0
# Last name     0
# First name    0
# Salary        0
# Benefits      0
# Employer      0
# Job title     0
# Year          0
# dtype: int64

# %%
salary_data['full_name'] = salary_data['First name'] + ' ' + salary_data['Last name']
salary_data['full_name']
# Out:
# 0               Cheri Aarts
# 1              Drew Aaslepp
# 2              Corinne Abba
# 3              Brian Abbott
# 4           Kathleen Abbott
#                ...
# 1495        John Cunningham
# 1496       Leigh Cunningham
# 1497    Marianne Cunningham
# 1498         Anthony Cupido
# 1499            June Cupido
# Name: full_name, Length: 1500, dtype: object

# %%
# Remove '$' and ',' from Salary and Benefits
salary_data['Salary'] = salary_data['Salary'].str.replace('[$,]','', regex=True)
salary_data['Benefits'] = salary_data['Benefits'].str.replace('[$,]','', regex=True)

# %%
salary_data['Salary'] = pd.to_numeric(salary_data['Salary'])
salary_data['Benefits'] = pd.to_numeric(salary_data['Benefits'])

# %%
salary_data['total_pay'] = salary_data['Salary'] + salary_data['Benefits']
salary_data['total_pay']
# Out:
# 0       113657.58
# 1       113803.11
# 2       102331.53
# 3       102972.82
# 4       161181.22
#           ...
# 1495    113153.74
# 1496    110184.03
# 1497    104467.37
# 1498    138914.32
# 1499    154220.65
# Name: total_pay, Length: 1500, dtype: float64

# %%
salary_data
# Out:
#        _id    Sector   Last name First name     Salary  Benefits
# 0        1  Colleges       Aarts      Cheri  113586.57     71.01  \
# 1        2  Colleges     Aaslepp       Drew  113685.85    117.26
# 2        3  Colleges        Abba    Corinne  102214.17    117.36
# 3        4  Colleges      Abbott      Brian  102855.46    117.36
# 4        5  Colleges      Abbott   Kathleen  160854.89    326.33
# ...    ...       ...         ...        ...        ...       ...
# 1495  1496  Colleges  Cunningham       John  113035.90    117.84
# 1496  1497  Colleges  Cunningham      Leigh  108974.47   1209.56
# 1497  1498  Colleges  Cunningham   Marianne  104251.26    216.11
# 1498  1499  Colleges      Cupido    Anthony  138634.58    279.74
# 1499  1500  Colleges      Cupido       June  154106.28    114.37
#
#                                                Employer
# 0       Fanshawe College Of Applied Arts and Technology  \
# 1     Humber College Institute Of Technology and Adv...
# 2     George Brown College Of Applied Arts and Techn...
# 3     Conestoga College Institute Of Technology and ...
# 4     George Brown College Of Applied Arts and Techn...
# ...                                                 ...
# 1495    Georgian College Of Applied Arts and Technology
# 1496  St Lawrence College Of Applied Arts and Techno...
# 1497      Seneca College Of Applied Arts and Technology
# 1498      Mohawk College Of Applied Arts and Technology
# 1499  Sheridan College Institute Of Technology and A...
#
#                                               Job title  Year
# 0                                             Professor  2020  \
# 1                                             Professor  2020
# 2                                             Librarian  2020
# 3                                             Professor  2020
# 4        Associate Dean, Centre for Continuous Learning  2020
# ...                                                 ...   ...
# 1495                                          Professor  2020
# 1496  Associate Director, Libraries and Student Success  2020
# 1497            Manager of Disability and Accommodation  2020
# 1498                     Research Chair, Sustainability  2020
# 1499                                Associate Registrar  2020
#
#                 full_name  total_pay
# 0             Cheri Aarts  113657.58
# 1            Drew Aaslepp  113803.11
# 2            Corinne Abba  102331.53
# 3            Brian Abbott  102972.82
# 4         Kathleen Abbott  161181.22
# ...                   ...        ...
# 1495      John Cunningham  113153.74
# 1496     Leigh Cunningham  110184.03
# 1497  Marianne Cunningham  104467.37
# 1498       Anthony Cupido  138914.32
# 1499          June Cupido  154220.65
#
# [1500 rows x 11 columns]

# %%
relevant_columns = ['full_name', 'total_pay']
clean_total_pay = salary_data[relevant_columns]
clean_total_pay
# Out:
#                 full_name  total_pay
# 0             Cheri Aarts  113657.58
# 1            Drew Aaslepp  113803.11
# 2            Corinne Abba  102331.53
# 3            Brian Abbott  102972.82
# 4         Kathleen Abbott  161181.22
# ...                   ...        ...
# 1495      John Cunningham  113153.74
# 1496     Leigh Cunningham  110184.03
# 1497  Marianne Cunningham  104467.37
# 1498       Anthony Cupido  138914.32
# 1499          June Cupido  154220.65
#
# [1500 rows x 2 columns]

# %%
db_secret = {
    'drivername': 'postgresql+psycopg2',
    'host'      : 'mmai5100postgres.canadacentral.cloudapp.azure.com',
    'port'      : '5432',
    'username'  : 'jreid9',
    'password'  : '2023!Schulich',
    'database'  : 'jreid9_db'
}

# %%
db_connection_url = sa.engine.URL.create(
    drivername = db_secret['drivername'],
    username   = db_secret['username'],
    password   = db_secret['password'],
    host       = db_secret['host'],
    port       = db_secret['port'],
    database   = db_secret['database']
)

# %%
db_connection_url
# Out:
# postgresql+psycopg2://jreid9:***@mmai5100postgres.canadacentral.cloudapp.azure.com:5432/jreid9_db

# %%
engine = sa.create_engine(db_connection_url)

# %%
with engine.connect() as connection:
    connection.execute('CREATE SCHEMA IF NOT EXISTS pipeline')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1408, in Connection.execute(self, statement, parameters, execution_options)
#    1407 try:
# -> 1408     meth = statement._execute_on_connection
#    1409 except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 with engine.connect() as connection:
# ----> 2     connection.execute('CREATE SCHEMA IF NOT EXISTS pipeline')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1410, in Connection.execute(self, statement, parameters, execution_options)
#    1408     meth = statement._execute_on_connection
#    1409 except AttributeError as err:
# -> 1410     raise exc.ObjectNotExecutableError(statement) from err
#    1411 else:
#    1412     return meth(
#    1413         self,
#    1414         distilled_parameters,
#    1415         execution_options or NO_OPTIONS,
#    1416     )
#
# ObjectNotExecutableError: Not an executable object: 'CREATE SCHEMA IF NOT EXISTS pipeline'

# %%
clean_total_pay.to_sql(
    name = 'total_pay', 
    schema = 'pipeline',
    con = engine,
    if_exists = 'replace',
    index = False,
    method = 'multi',
    dtype = {
        'full_name'  : sa.types.VARCHAR(50),
        'total_pay'  : sa.types.DECIMAL(10,2)
    }
)
# Out:
# 1500
